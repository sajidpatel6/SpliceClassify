# %% [markdown]
# Import libraries requred for the script

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
from numpy.polynomial import polynomial as npp
from scipy.stats import linregress

# %% [markdown]
# Read the CSV files

# %%
df_pa = pd.read_csv('VMI_Data_PA_V02_AK6_mod.csv')
df_bp1 = pd.read_csv('VMI_Data_BP1_V02_AK6_mod.csv')
df_bp2 = pd.read_csv('VMI_Data_BP2_V02_AK6_mod.csv')

# %% [markdown]
# Check the columns in the data

# %%
print(df_pa.columns)
print(df_bp1.columns)
print(df_bp2.columns)

# %%
df_pa.dtypes

# %% [markdown]
# Check missing data

# %%
total = df_pa.isnull().sum().sort_values(ascending=False)
percent = (df_pa.isnull().sum()/df_pa.isnull().count()*100).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
print(missing_data.head(20))
df_pa = df_pa.dropna()

total = df_bp1.isnull().sum().sort_values(ascending=False)
percent = (df_bp1.isnull().sum()/df_bp1.isnull().count()*100).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
print(missing_data.head(20))
df_bp1 = df_bp1.dropna()

total = df_bp2.isnull().sum().sort_values(ascending=False)
percent = (df_bp2.isnull().sum()/df_bp2.isnull().count()*100).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
print(missing_data.head(20))
df_bp2 = df_bp2.dropna()

# %%
total = df_pa.isnull().sum().sort_values(ascending=False)
percent = (df_pa.isnull().sum()/df_pa.isnull().count()*100).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
print(missing_data.head(20))

total = df_bp1.isnull().sum().sort_values(ascending=False)
percent = (df_bp1.isnull().sum()/df_bp1.isnull().count()*100).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
print(missing_data.head(20))

total = df_bp2.isnull().sum().sort_values(ascending=False)
percent = (df_bp2.isnull().sum()/df_bp2.isnull().count()*100).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
print(missing_data.head(20))

# %%
#skewness and kurtosis
print("Skewness: %f" % df_pa['CUT_LENGTH'].skew())
print("Kurtosis: %f" % df_pa['CUT_LENGTH'].kurt())

# %%
#skewness and kurtosis
print("Skewness: %f" % df_pa['CONV_WAIT_TIME'].skew())
print("Kurtosis: %f" % df_pa['CONV_WAIT_TIME'].kurt())

# %%
df_pa['LFT_SPLICE_LENGTH'].describe()

# %%
df_pa['MID_SPLICE_LENGTH'].describe()

# %%
df_pa['RHT_SPLICE_LENGTH'].describe()

# %%
#histogram
sns.distplot(df_pa['LFT_SPLICE_LENGTH']);

# %%
#histogram
sns.distplot(df_pa['MID_SPLICE_LENGTH']);

# %%
#histogram
sns.distplot(df_pa['RHT_SPLICE_LENGTH']);

# %%
#histogram
sns.distplot(df_pa['LFT_SPLICE_DELTA']);

# %%
#histogram
sns.distplot(df_pa['MID_SPLICE_DELTA']);

# %%
#histogram
sns.distplot(df_pa['RHT_SPLICE_DELTA']);

# %%
#scatter plot
var = 'CONV_WAIT_TIME'
data = pd.concat([df_pa['CUT_LENGTH'], df_pa[var]], axis=1)
data.plot.scatter(x=var, y='CUT_LENGTH');

# %%
#scatter plot
var = 'PA_S1_ML'
data = pd.concat([df_pa['MID_SPLICE_LENGTH'], df_pa[var]], axis=1)
data.plot.scatter(x=var, y='MID_SPLICE_LENGTH');

# %%
#box plot
var = 'PA_S1_ML'
data = pd.concat([df_pa['MID_SPLICE_LENGTH'], df_pa[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="MID_SPLICE_LENGTH", data=data)
fig.axis(ymin=10, ymax=25);

# %%
#correlation matrix
corrmat = df_pa.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
# correlation matrix
k = 20 #number of variables for heatmap
cols = corrmat.nlargest(k, 'SPLICE_OK')['SPLICE_OK'].index
cm = np.corrcoef(df_pa[cols].values.T)
sns.set(font_scale=0.9)
f, ax = plt.subplots(figsize=(20, 20))
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %%
# df_pa.columns

# %%
#scatterplot
#sns.set()
#cols = ['CUT_LENGTH', 'CONV_WAIT_TIME', 'LFT_SPLICE_LENGTH', 
#        'LFT_SPLICE_DELTA', 'LFT_SPLICE_MA5', 'LFT_SPLICE_MA10',
#        'LFT_SPLICE_MA20', 'LFT_SPLICE_MA50', 'MID_SPLICE_LENGTH', 
#        'RHT_SPLICE_LENGTH', 'SPLICE_OK', 'PA_S8_L', 'PA_S7_L',
#        'PA_S6_L', 'PA_S5_L', 'PA_S4_L', 'PA_S3_L', 'PA_S2_L',
#        'PA_S1_ML', 'PA_S1_MR', 'PA_S2_R', 'PA_S3_R', 'PA_S4_R',
#        'PA_S5_R', 'PA_S6_R', 'PA_S7_R', 'PA_S8_R']
#sns.pairplot(df_pa[cols], size = 2.5)
#plt.show();
#sns.pairplot(df_pa)

# %%
# 'ID', 'MACHINE_ID', 'DATE_TIME_STAMP', 'GT_BARCODE', 'TIRE_TYPE',
# 'CUT_LENGTH', 'CONV_WAIT_TIME', 'LFT_SPLICE_LENGTH',
# 'MID_SPLICE_LENGTH', 'RHT_SPLICE_LENGTH', 'SPLICE_LIMIT_LOW',
# 'SPLICE_LIMIT_HIGH', 'SPLICE_OK', 'PA_S8_L', 'PA_S7_L', 'PA_S6_L',
# 'PA_S5_L', 'PA_S4_L', 'PA_S3_L', 'PA_S2_L', 'PA_S1_ML', 'PA_S1_MR',
# 'PA_S2_R', 'PA_S3_R', 'PA_S4_R', 'PA_S5_R', 'PA_S6_R', 'PA_S7_R',
# 'PA_S8_R', 'PA_PART', 'PA_BARCODE', 'BP1_LENGTH', 'PA_BUILD_DATE',
# 'PA_MACHINEID', 'LFT_SPLICE_DELTA', 'LFT_SPLICE_PREV', 'LFT_SPLICE_MA5',
# 'LFT_SPLICE_MA10', 'LFT_SPLICE_MA20', 'LFT_SPLICE_MA50',
# 'LFT_SPLICE_SLOPE5', 'LFT_SPLICE_SLOPE10', 'LFT_SPLICE_SLOPE20',
# 'LFT_SPLICE_SLOPE50', 'MID_SPLICE_DELTA', 'MID_SPLICE_PREV',
# 'MID_SPLICE_MA5', 'MID_SPLICE_MA10', 'MID_SPLICE_MA20',
# 'MID_SPLICE_MA50', 'MID_SPLICE_SLOPE5', 'MID_SPLICE_SLOPE10',
# 'MID_SPLICE_SLOPE20', 'MID_SPLICE_SLOPE50', 'RHT_SPLICE_DELTA',
# 'RHT_SPLICE_PREV', 'RHT_SPLICE_MA5', 'RHT_SPLICE_MA10',
# 'RHT_SPLICE_MA20', 'RHT_SPLICE_MA50', 'RHT_SPLICE_SLOPE5',
# 'RHT_SPLICE_SLOPE10', 'RHT_SPLICE_SLOPE20', 'RHT_SPLICE_SLOPE50'

data = []
for f in df_pa.columns:
    # Defining the role
    if f == 'SPLICE_OK':
        role = 'target'
    elif f in ['ID','MACHINE_ID','DATE_TIME_STAMP','GT_BARCODE','TIRE_TYPE','SPLICE_LIMIT_LOW',
               'SPLICE_LIMIT_HIGH','PA_PART','PA_BARCODE', 'PA_BUILD_DATE','PA_MACHINEID']:
        role = 'id'
    else:
        role = 'input'
         
    # Defining the level
    if f == 'SPLICE_OK':
        opType = 'binary'
    elif f == 'DATE_TIME_STAMP':
        opType = 'timestamp'
    elif df_pa[f].dtype == object:
        opType = 'nominal'
    elif df_pa[f].dtype == bool:
        opType = 'binary'
    elif df_pa[f].dtype == int:
        opType = 'interval'
    elif df_pa[f].dtype == float:
        opType = 'interval'
    else :
        opType = 'interval'
        
    # Initialize keep to True for all variables except for id
    keep = True
    if f in ['ID','MACHINE_ID','DATE_TIME_STAMP','GT_BARCODE','TIRE_TYPE','SPLICE_LIMIT_LOW',
               'SPLICE_LIMIT_HIGH','PA_PART','PA_BARCODE', 'PA_BUILD_DATE','PA_MACHINEID']:
        keep = False
    
    # Defining the data type 
    dtype = df_pa[f].dtype
    
    # Creating a Dict that contains all the metadata for the variable
    f_dict = {
        'varname': f,
        'role': role,
        'level': opType,
        'keep': keep,
        'dtype': dtype
    }
    data.append(f_dict)
    
meta = pd.DataFrame(data, columns=['varname', 'role', 'level', 'keep', 'dtype'])
meta.set_index('varname', inplace=True)

# %%
meta

# %%
meta[(meta.level == 'interval') & (meta.keep)].index

# %%
pd.DataFrame({'count' : meta.groupby(['role', 'level'])['role'].size()}).reset_index()

# %%
v = meta[(meta.level == 'interval') & (meta.keep)].index
df_pa[v].describe()

# %%
v = meta[(meta.level == 'binary') & (meta.keep)].index
df_pa[v].describe()

# %%
df_pa.columns

# %%
df_pa.CUT_LENGTH.describe()

# %%
#standardizing data
cut_length_scaled = StandardScaler().fit_transform(df_pa['CUT_LENGTH'][:,np.newaxis]);
low_range = cut_length_scaled[cut_length_scaled[:,0].argsort()][:10]
high_range= cut_length_scaled[cut_length_scaled[:,0].argsort()][-10:]
print('outer range (low) of the distribution:')
print(low_range)
print('\nouter range (high) of the distribution:')
print(high_range)

# %%
#bivariate analysis
var = 'PA_S1_ML'
data = pd.concat([df_pa['CUT_LENGTH'], df_pa[var]], axis=1)
data.plot.scatter(x=var, y='CUT_LENGTH');

# %%
#deleting points
df_pa.sort_values(by = 'CUT_LENGTH', ascending = False)[:2]
df_pa = df_pa.drop(df_pa[df_pa['CUT_LENGTH'] > 1720].index)
df_pa = df_pa.drop(df_pa[df_pa['CUT_LENGTH'] < 1660].index)

# %%
#bivariate analysis saleprice/grlivarea
var = 'PA_S1_ML'
data = pd.concat([df_pa['CUT_LENGTH'], df_pa[var]], axis=1)
data.plot.scatter(x=var, y='CUT_LENGTH');

# %%
#bivariate analysis saleprice/grlivarea
var = 'PA_S8_L'
data = pd.concat([df_pa['CUT_LENGTH'], df_pa[var]], axis=1)
data.plot.scatter(x=var, y='CUT_LENGTH');

# %%
#histogram and normal probability plot
sns.distplot(df_pa['CUT_LENGTH'], fit=norm);
fig = plt.figure()
res = stats.probplot(df_pa['CUT_LENGTH'], plot=plt)

# %%
#applying log transformation
df_pa['CUT_LENGTH_LOG'] = np.log(df_pa['CUT_LENGTH'])

# %%
#transformed histogram and normal probability plot
sns.distplot(df_pa['CUT_LENGTH_LOG'], fit=norm);
fig = plt.figure()
res = stats.probplot(df_pa['CUT_LENGTH_LOG'], plot=plt)

# %%
df_pa = df_pa.drop('CUT_LENGTH_LOG',1)

# %%
#transformed histogram and normal probability plot
sns.distplot(df_pa['LFT_SPLICE_LENGTH'], fit=norm);
fig = plt.figure()
res = stats.probplot(df_pa['LFT_SPLICE_LENGTH'], plot=plt)

# %%
#transformed histogram and normal probability plot
sns.distplot(df_pa['MID_SPLICE_LENGTH'], fit=norm);
fig = plt.figure()
res = stats.probplot(df_pa['MID_SPLICE_LENGTH'], plot=plt)

# %%
#transformed histogram and normal probability plot
sns.distplot(df_pa['RHT_SPLICE_LENGTH'], fit=norm);
fig = plt.figure()
res = stats.probplot(df_pa['RHT_SPLICE_LENGTH'], plot=plt)

# %%
#correlation map
f,ax = plt.subplots(figsize=(25, 25))
sns.set(font_scale=0.8)
sns.heatmap(df_pa.corr(), annot=True, linewidths=.2, fmt= '.1f',ax=ax)
plt.show()

# %%
lft_bins = [df_pa['LFT_SPLICE_LENGTH'].min(),3.5, df_pa['LFT_SPLICE_LENGTH'].mean(),
        11.0,df_pa['LFT_SPLICE_LENGTH'].max()]

mid_bins = [df_pa['MID_SPLICE_LENGTH'].min(),4.9, df_pa['MID_SPLICE_LENGTH'].mean(),
        18.0,df_pa['MID_SPLICE_LENGTH'].max()]

rht_bins = [df_pa['RHT_SPLICE_LENGTH'].min(),3.5, df_pa['RHT_SPLICE_LENGTH'].mean(),
        11.0,df_pa['RHT_SPLICE_LENGTH'].max()]

# %%
df_pa.columns

# %%
mid_bins

# %%
bin_names=['Bad','Good','GoodH','BadH']

# %%
bin_names

# %%
df_pa['LFT_SPLICE_GRADE'] = pd.cut(df_pa['LFT_SPLICE_LENGTH'],lft_bins, labels=bin_names, include_lowest=True).str.replace('H','')
df_pa['MID_SPLICE_GRADE'] = pd.cut(df_pa['MID_SPLICE_LENGTH'],mid_bins, labels=bin_names, include_lowest=True).str.replace('H','')
df_pa['RHT_SPLICE_GRADE'] = pd.cut(df_pa['RHT_SPLICE_LENGTH'],rht_bins, labels=bin_names, include_lowest=True).str.replace('H','')
df_pa['SPLICE_GRADE'] = df_pa['LFT_SPLICE_GRADE']
df_pa['SPLICE_GRADE'][df_pa.MID_SPLICE_GRADE == 'Bad'] = df_pa['MID_SPLICE_GRADE'] 
df_pa['SPLICE_GRADE'][df_pa.RHT_SPLICE_GRADE == 'Bad'] = df_pa['RHT_SPLICE_GRADE']
#df_pa['LFT_SPLICE_GRADE'] = pd.cut(df_pa['LFT_SPLICE_LENGTH'],bins, include_lowest=True)

# %%
#df_pa['LFT_SPLICE_GRADE']
#one_hot=pd.get_dummies(df_pa['LFT_SPLICE_GRADE'])
#df_pa = df_pa.drop('LFT_SPLICE_GRADE', axis = 1)
#df_pa = df_pa.join(one_hot)
#df_a.join(df_b, on='mukey', how='left', lsuffix='_left', rsuffix='_right')

# %%
#correlation map
f,ax = plt.subplots(figsize=(25, 25))
sns.set(font_scale=0.9)
sns.heatmap(df_pa.corr(), annot=True, linewidths=.2, fmt= '.1f',ax=ax)
plt.show()

# %%
#from bokeh.charts import HeatMap, bins, output_file, show, vplot
#hm1 = HeatMap(autompg, x=bins('mpg'), y=bins('displ'))

df_pa.shape

# %%
#from scipy import stats
#df_pa[(np.abs(stats.zscore(df_pa)) < 3).all(axis=1)]

# sns.set(style="ticks", color_codes=True)
# sns.pairplot(df_pa[['CUT_LENGTH', 'CONV_WAIT_TIME', 'LFT_SPLICE_LENGTH']])
# plt.show()

# %%
# cols = ['CUT_LENGTH', 'CONV_WAIT_TIME', 'LFT_SPLICE_LENGTH',
#        'MID_SPLICE_LENGTH', 'RHT_SPLICE_LENGTH', #'SPLICE_OK', 
#         'PA_S8_L', 'PA_S7_L', 'PA_S6_L',
#        'PA_S5_L', 'PA_S4_L', 'PA_S3_L', 'PA_S2_L', 'PA_S1_ML', 'PA_S1_MR',
#        'PA_S2_R', 'PA_S3_R', 'PA_S4_R', 'PA_S5_R', 'PA_S6_R', 'PA_S7_R',
#        'PA_S8_R', 'LFT_SPLICE_DELTA', 'LFT_SPLICE_PREV', 'LFT_SPLICE_MA5',
#        'LFT_SPLICE_MA10', 'LFT_SPLICE_MA20', 'LFT_SPLICE_MA50',
#        'LFT_SPLICE_SLOPE5', 'LFT_SPLICE_SLOPE10', 'LFT_SPLICE_SLOPE20',
#        'LFT_SPLICE_SLOPE50', 'MID_SPLICE_DELTA', 'MID_SPLICE_PREV',
#        'MID_SPLICE_MA5', 'MID_SPLICE_MA10', 'MID_SPLICE_MA20',
#        'MID_SPLICE_MA50', 'MID_SPLICE_SLOPE5', 'MID_SPLICE_SLOPE10',
#        'MID_SPLICE_SLOPE20', 'MID_SPLICE_SLOPE50', 'RHT_SPLICE_DELTA',
#        'RHT_SPLICE_PREV', 'RHT_SPLICE_MA5', 'RHT_SPLICE_MA10',
#        'RHT_SPLICE_MA20', 'RHT_SPLICE_MA50', 'RHT_SPLICE_SLOPE5',
#        'RHT_SPLICE_SLOPE10', 'RHT_SPLICE_SLOPE20', 'RHT_SPLICE_SLOPE50']

#sns.pairplot(df_pa[cols])

ycols = ['LFT_SPLICE_DELTA', 'MID_SPLICE_DELTA','RHT_SPLICE_DELTA', 'SPLICE_OK']

xcols = ['CUT_LENGTH', 'CONV_WAIT_TIME', #'LFT_SPLICE_LENGTH', 'MID_SPLICE_LENGTH', 'RHT_SPLICE_LENGTH','PA_S8_L', 'PA_S7_L', 'PA_S6_L', 'PA_S5_L', 'PA_S4_L', 
         'PA_S3_L', 'PA_S2_L', 'PA_S1_ML', 'PA_S1_MR','PA_S2_R', 'PA_S3_R', 
         'PA_S4_R', 'PA_S5_R', 'PA_S6_R', 'PA_S7_R', 'PA_S8_R', 
         'LFT_SPLICE_PREV', 'LFT_SPLICE_MA5', 'LFT_SPLICE_MA10', 
#          'LFT_SPLICE_MA20', 'LFT_SPLICE_MA50',
         'LFT_SPLICE_SLOPE5', 'LFT_SPLICE_SLOPE10', 
#          'LFT_SPLICE_SLOPE20', 'LFT_SPLICE_SLOPE50', 
         'MID_SPLICE_PREV',
         'MID_SPLICE_MA5', 'MID_SPLICE_MA10', 
#          'MID_SPLICE_MA20', 'MID_SPLICE_MA50', 
         'MID_SPLICE_SLOPE5', 'MID_SPLICE_SLOPE10',
#          'MID_SPLICE_SLOPE20', 'MID_SPLICE_SLOPE50', 
         'RHT_SPLICE_PREV', 'RHT_SPLICE_MA5', 'RHT_SPLICE_MA10',
#          'RHT_SPLICE_MA20', 'RHT_SPLICE_MA50', 
         'RHT_SPLICE_SLOPE5',
         'RHT_SPLICE_SLOPE10', 
#          'RHT_SPLICE_SLOPE20', 'RHT_SPLICE_SLOPE50'
        ]

# df_pa_sample=df_pa.sample(10000)
sns.set(style="ticks", color_codes=True)
# plot_kws={"s": 0.1}
g = sns.pairplot(df_pa, x_vars=xcols, y_vars=ycols, hue='SPLICE_GRADE', plot_kws = {'alpha': 0.5, 's': 10}) #,'edgecolor': 'b'

xlabels,ylabels = [],[]

for ax in g.axes[-1,:]:
    xlabel = ax.xaxis.get_label_text()
    xlabels.append(xlabel)
for ax in g.axes[:,0]:
    ylabel = ax.yaxis.get_label_text()
    ylabels.append(ylabel)

for i in range(len(xlabels)):
    for j in range(len(ylabels)):
        g.axes[j,i].xaxis.set_label_text(xlabels[i])
        g.axes[j,i].yaxis.set_label_text(ylabels[j])

plt.show()

# %%
# sns.set(style="ticks", color_codes=True)
# cols = ['CUT_LENGTH', 'CONV_WAIT_TIME', 'LFT_SPLICE_LENGTH',
#        'MID_SPLICE_LENGTH', 'RHT_SPLICE_LENGTH', #'SPLICE_OK', 
#         'PA_S8_L', 'PA_S7_L', 'PA_S6_L',
#        'PA_S5_L', 'PA_S4_L', 'PA_S3_L', 'PA_S2_L', 'PA_S1_ML', 'PA_S1_MR',
#        'PA_S2_R', 'PA_S3_R', 'PA_S4_R', 'PA_S5_R', 'PA_S6_R', 'PA_S7_R',
#        'PA_S8_R', 'LFT_SPLICE_DELTA', 'LFT_SPLICE_PREV', 'LFT_SPLICE_MA5',
#        'LFT_SPLICE_MA10', 'LFT_SPLICE_MA20', 'LFT_SPLICE_MA50',
#        'LFT_SPLICE_SLOPE5', 'LFT_SPLICE_SLOPE10', 'LFT_SPLICE_SLOPE20',
#        'LFT_SPLICE_SLOPE50', 'MID_SPLICE_DELTA', 'MID_SPLICE_PREV',
#        'MID_SPLICE_MA5', 'MID_SPLICE_MA10', 'MID_SPLICE_MA20',
#        'MID_SPLICE_MA50', 'MID_SPLICE_SLOPE5', 'MID_SPLICE_SLOPE10',
#        'MID_SPLICE_SLOPE20', 'MID_SPLICE_SLOPE50', 'RHT_SPLICE_DELTA',
#        'RHT_SPLICE_PREV', 'RHT_SPLICE_MA5', 'RHT_SPLICE_MA10',
#        'RHT_SPLICE_MA20', 'RHT_SPLICE_MA50', 'RHT_SPLICE_SLOPE5',
#        'RHT_SPLICE_SLOPE10', 'RHT_SPLICE_SLOPE20', 'RHT_SPLICE_SLOPE50','SPLICE_GRADE']
# df_pa_sample=df_pa.sample(10000)
# sns.pairplot(df_pa_sample[cols],hue='SPLICE_GRADE', plot_kws = {'s': 10}) #, 'edgecolor': 'none'
# plt.show()

# %%
#df_pa.shape
# sns.pairplot(df_pa)
# plt.show()

# %%
# sns.set(style="ticks", color_codes=True)
# sns.pairplot(data=df_pa,hue='SPLICE_OK')
# plt.show()

# %%
# # correlation matrix
# k = 20 #number of variables for heatmap
# cols = corrmat.nlargest(k, 'RHT_SPLICE_DELTA')['RHT_SPLICE_DELTA'].index
# cm = np.corrcoef(df_pa[cols].values.T)
# sns.set(font_scale=0.9)
# f, ax = plt.subplots(figsize=(20, 20))
# hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
# plt.show()

# %%
# # correlation matrix
# k = 20 #number of variables for heatmap
# cols = corrmat.nlargest(k, 'LFT_SPLICE_DELTA')['LFT_SPLICE_DELTA'].index
# cm = np.corrcoef(df_pa[cols].values.T)
# sns.set(font_scale=0.9)
# f, ax = plt.subplots(figsize=(20, 20))
# hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
# plt.show()

# %%
#scatterplot
#sns.set()
#sns.pairplot(df_pa, size = 2.5)
#plt.show();

# %%
#scatterplot
# sns.set()
# sns.pairplot(df_pa, size = 2.5)
# plt.show();

# %%
# sns.pairplot(df_pa[['CUT_LENGTH', 'CONV_WAIT_TIME', 'LFT_SPLICE_LENGTH']], size = 2.5, hue = 'SPLICE_OK')

# %%
# df_pa.hist()
# plt.show()

# %%
#df_pa.plot(kind='density', subplots=True, layout=(3,3), sharex=False)
#df_pa.plot(kind='density', subplots=True)
#plt.show()

# %%
# Scatterplot Matrix
# import matplotlib.pyplot as plt
# import pandas
# from pandas.plotting import scatter_matrix
# scatter_matrix(df_pa)
# plt.show()

# %%
# def core(df, α=.05):
#     mask = (df > df.quantile(α)).all(1) & (df < df.quantile(1 - α)).all(1)
#     return df[mask]

# %%
# cmap = sns.cubehelix_palette(as_cmap=True, dark=0, light=1, reverse=True)

# (df_pa.select_dtypes(include=[np.number])
#    .pipe(core)
#    .pipe(sns.PairGrid)
#    .map_upper(plt.scatter, marker='.', alpha=.25)
#    .map_diag(sns.kdeplot)
#    .map_lower(plt.hexbin, cmap=cmap, gridsize=20)
# );

# %%
# sns.pairplot(df_pa, hue = 'SPLICE_OK', diag_kind = 'kde',
#              plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'},
#              size = 4)

# %%
# todo
# grr = pd.scatter_matrix(df_pa, c=Y, figsize=(15, 15), marker='o',
#                         hist_kwds={'bins': 20}, s=60, alpha=.8)

# %%
# todo
# # Plot colored by continent for years 2000-2007
# sns.pairplot(df[df['year'] >= 2000], 
#              vars = ['life_exp', 'log_pop', 'log_gdp_per_cap'], 
#              hue = 'continent', diag_kind = 'kde', 
#              plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'},
#              size = 4);

# # Title 
# plt.suptitle('Pair Plot of Socioeconomic Data for 2000-2007', 
#              size = 28);

# %%
# https://towardsdatascience.com/visualizing-data-with-pair-plots-in-python-f228cf529166

# %%
# https://stackoverflow.com/questions/42592493/displaying-pair-plot-in-pandas-data-frame/42593334

# %%
df_pa_sample=df_pa.sample(500)
# sns.set(style="ticks", color_codes=True)
# g = sns.pairplot(df_pa_sample, hue='SPLICE_GRADE')
# plt.show()

# %%
# g = sns.PairGrid(df_pa_sample)
# g = g.map(plt.scatter)

# xlabels,ylabels = [],[]

# for ax in g.axes[-1,:]:
#     xlabel = ax.xaxis.get_label_text()
#     xlabels.append(xlabel)
# for ax in g.axes[:,0]:
#     ylabel = ax.yaxis.get_label_text()
#     ylabels.append(ylabel)

# for i in range(len(xlabels)):
#     for j in range(len(ylabels)):
#         g.axes[j,i].xaxis.set_label_text(xlabels[i])
#         g.axes[j,i].yaxis.set_label_text(ylabels[j])

# plt.show()

# %%
# https://jovianlin.io/data-visualization-seaborn-part-3/

# %%
pd.DataFrame({'count' : df_pa.groupby(['SPLICE_GRADE'])['RHT_SPLICE_DELTA'].size()}).reset_index()

# %%
pd.DataFrame({'count' : df_pa.groupby(['SPLICE_OK'])['RHT_SPLICE_DELTA'].size()}).reset_index()

# %%
df_pa.to_csv('VMI_Data_PA_V02_AK6_new.csv', header=True, index=False)
