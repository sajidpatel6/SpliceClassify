# %% [markdown]
# Import python libraries required for the script

# %%
from rfpimp import *
from sklearn.ensemble import RandomForestClassifier #, VotingClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from scipy import stats
from scipy.stats import norm

import itertools as it
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
rfc = RandomForestClassifier(n_estimators=300, warm_start=True)

# %% [markdown]
# Read the CSV files

# %%
df = pd.read_csv('VMI_Data_BP1_V02_AK6_mod02.csv')
print(df.columns)
# Out:
# Index(['CUT_LENGTH', 'CONV_WAIT_TIME', 'LFT_SPLICE_LENGTH',
#        'MID_SPLICE_LENGTH', 'RHT_SPLICE_LENGTH', 'SPLICE_OK', 'BP1_S8_L',
#        'BP1_S7_L', 'BP1_S6_L', 'BP1_S5_L', 'BP1_S4_L', 'BP1_S3_L', 'BP1_S2_L',
#        'BP1_S1_ML', 'BP1_S1_MR', 'BP1_S2_R', 'BP1_S3_R', 'BP1_S4_R',
#        'BP1_S5_R', 'BP1_S6_R', 'BP1_S7_R', 'BP1_S8_R', 'PART_LENGTH',
#        'LFT_SPLICE_DELTA', 'LFT_SPLICE_PREV', 'LFT_SPLICE_MA5',
#        'LFT_SPLICE_MA10', 'LFT_SPLICE_MA20', 'LFT_SPLICE_MA50',
#        'LFT_SPLICE_SLOPE5', 'LFT_SPLICE_SLOPE10', 'LFT_SPLICE_SLOPE20',
#        'LFT_SPLICE_SLOPE50', 'MID_SPLICE_DELTA', 'MID_SPLICE_PREV',
#        'MID_SPLICE_MA5', 'MID_SPLICE_MA10', 'MID_SPLICE_MA20',
#        'MID_SPLICE_MA50', 'MID_SPLICE_SLOPE5', 'MID_SPLICE_SLOPE10',
#        'MID_SPLICE_SLOPE20', 'MID_SPLICE_SLOPE50', 'RHT_SPLICE_DELTA',
#        'RHT_SPLICE_PREV', 'RHT_SPLICE_MA5', 'RHT_SPLICE_MA10',
#        'RHT_SPLICE_MA20', 'RHT_SPLICE_MA50', 'RHT_SPLICE_SLOPE5',
#        'RHT_SPLICE_SLOPE10', 'RHT_SPLICE_SLOPE20', 'RHT_SPLICE_SLOPE50',
#        'LFT_SPLICE_GRADE', 'MID_SPLICE_GRADE', 'RHT_SPLICE_GRADE',
#        'SPLICE_GRADE'],
#       dtype='object')

# %%
# pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_columns', None) 

df.describe()
# df.astype(bool).sum(axis=0)
# Out:
#           CUT_LENGTH  CONV_WAIT_TIME  LFT_SPLICE_LENGTH  MID_SPLICE_LENGTH  \
# count  118264.000000   118264.000000      118264.000000      118264.000000
# mean     1707.480208       79.453379           6.773963           7.218014
# std         7.292843      198.349929           2.273400           1.922907
# min         0.000000        0.000000         -47.200000         -56.381480
# 25%      1706.443000       28.620000           5.535539           6.239172
# 50%      1707.684000       34.272000           6.866215           7.265045
# 75%      1708.775000       64.398250           8.122182           8.331148
# max      1719.298000    10034.240000          29.686790          26.034800
#
#        RHT_SPLICE_LENGTH     SPLICE_OK       BP1_S8_L       BP1_S7_L  \
# count      118264.000000  118264.00000  118264.000000  118264.000000
# mean            7.005018       0.81543       0.000396       0.013105
# std             2.331694       0.38795       0.002635       0.043858
# min           -44.709190       0.00000       0.000000       0.000000
# 25%             5.735280       1.00000       0.000000       0.000000
# 50%             7.085455       1.00000       0.000000       0.000000
# 75%             8.429698       1.00000       0.000000       0.000000
# max            24.689260       1.00000       0.138328       0.350000
#
#             BP1_S6_L       BP1_S5_L       BP1_S4_L       BP1_S3_L  \
# count  118264.000000  118264.000000  118264.000000  118264.000000
# mean        0.012412       0.066963       0.064393       0.064773
# std         0.042574       0.043583       0.041481       0.040025
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.040000       0.040000       0.040000
# 50%         0.000000       0.070000       0.060000       0.070000
# 75%         0.000000       0.090000       0.090000       0.090000
# max         0.350000       0.500000       0.800000       0.500000
#
#             BP1_S2_L      BP1_S1_ML      BP1_S1_MR       BP1_S2_R  \
# count  118264.000000  118264.000000  118264.000000  118264.000000
# mean        0.062155       0.075592       0.074975       0.051929
# std         0.039990       0.040380       0.037706       0.040711
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.040000       0.050000       0.050000       0.010000
# 50%         0.060000       0.080000       0.080000       0.050000
# 75%         0.090000       0.100000       0.100000       0.080000
# max         0.900000       0.900000       2.000000       0.760000
#
#             BP1_S3_R       BP1_S4_R       BP1_S5_R       BP1_S6_R  \
# count  118264.000000  118264.000000  118264.000000  118264.000000
# mean        0.052364       0.052533       0.052831       0.009112
# std         0.040350       0.041165       0.041954       0.031093
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.010000       0.010000       0.010000       0.000000
# 50%         0.050000       0.050000       0.050000       0.000000
# 75%         0.080000       0.080000       0.080000       0.000000
# max         0.760000       0.900000       1.000000       0.760000
#
#             BP1_S7_R       BP1_S8_R    PART_LENGTH  LFT_SPLICE_DELTA  \
# count  118264.000000  118264.000000  118264.000000     118264.000000
# mean        0.007223       0.000420      42.352922         -0.476037
# std         0.025236       0.002768      58.228211          2.273400
# min         0.000000       0.000000       1.000000        -54.450000
# 25%         0.000000       0.000000      18.000000         -1.714461
# 50%         0.000000       0.000000      36.000000         -0.383785
# 75%         0.000000       0.000000      55.000000          0.872182
# max         0.250000       0.138328     999.000000         22.436790
#
#        LFT_SPLICE_PREV  LFT_SPLICE_MA5  LFT_SPLICE_MA10  LFT_SPLICE_MA20  \
# count    118264.000000   118264.000000    118264.000000    118264.000000
# mean         -0.476091       -0.476079        -0.476069        -0.475998
# std           2.273485        1.708936         1.523298         1.346469
# min         -54.450000      -27.173353       -15.133216        -7.947873
# 25%          -1.714570       -1.459353        -1.414423        -1.347475
# 50%          -0.383785       -0.455766        -0.479311        -0.510464
# 75%           0.872182        0.567864         0.480808         0.389080
# max          22.436790       12.431102         8.291490         5.000289
#
#        LFT_SPLICE_MA50  LFT_SPLICE_SLOPE5  LFT_SPLICE_SLOPE10  \
# count    118264.000000      118264.000000       118264.000000
# mean         -0.475945          -0.000004           -0.000005
# std           1.108978           0.631767            0.277010
# min          -5.769553         -15.350425           -5.553173
# 25%          -1.209058          -0.292147           -0.128236
# 50%          -0.513711          -0.009103           -0.003553
# 75%           0.225752           0.280719            0.120715
# max           4.505002          13.639248            5.848552
#
#        LFT_SPLICE_SLOPE20  LFT_SPLICE_SLOPE50  MID_SPLICE_DELTA  \
# count       118264.000000       118264.000000     118264.000000
# mean            -0.000013           -0.000002         -4.231986
# std              0.127321            0.047321          1.922907
# min             -1.548232           -0.327986        -67.831480
# 25%             -0.064984           -0.028347         -5.210828
# 50%             -0.001378            0.000407         -4.184955
# 75%              0.063047            0.028736         -3.118852
# max              1.758048            0.303629         14.584800
#
#        MID_SPLICE_PREV  MID_SPLICE_MA5  MID_SPLICE_MA10  MID_SPLICE_MA20  \
# count    118264.000000   118264.000000    118264.000000    118264.000000
# mean         -4.232034       -4.232078        -4.232102        -4.232144
# std           1.922982        1.481406         1.331663         1.200276
# min         -67.831480      -34.943143       -20.376426       -12.748412
# 25%          -5.210828       -5.085565        -5.051253        -5.007638
# 50%          -4.184955       -4.241799        -4.252305        -4.272749
# 75%          -3.118852       -3.326335        -3.393272        -3.460508
# max          14.584800        9.431126         6.906962         3.942696
#
#        MID_SPLICE_MA50  MID_SPLICE_SLOPE5  MID_SPLICE_SLOPE10  \
# count    118264.000000      118264.000000       118264.000000
# mean         -4.232261           0.000017            0.000010
# std           1.022789           0.545135            0.230315
# min          -7.913941         -18.788728           -6.500130
# 25%          -4.920288          -0.221473           -0.087134
# 50%          -4.294955           0.001389            0.007704
# 75%          -3.587266           0.231194            0.099097
# max           0.200878          17.390204            6.415370
#
#        MID_SPLICE_SLOPE20  MID_SPLICE_SLOPE50  RHT_SPLICE_DELTA  \
# count       118264.000000       118264.000000     118264.000000
# mean             0.000009            0.000009         -0.244982
# std              0.103159            0.038921          2.331694
# min             -1.864920           -0.292201        -51.959190
# 25%             -0.041252           -0.021967         -1.514720
# 50%              0.006400            0.001404         -0.164545
# 75%              0.049679            0.022616          1.179698
# max              1.849446            0.373360         17.439260
#
#        RHT_SPLICE_PREV  RHT_SPLICE_MA5  RHT_SPLICE_MA10  RHT_SPLICE_MA20  \
# count    118264.000000   118264.000000    118264.000000    118264.000000
# mean         -0.245026       -0.244978        -0.244936        -0.244910
# std           2.331730        1.800117         1.614783         1.422309
# min         -51.959190      -23.635951       -11.243221        -6.939771
# 25%          -1.514720       -1.270943        -1.230449        -1.168888
# 50%          -0.164545       -0.178076        -0.209232        -0.251774
# 75%           1.179698        0.875626         0.789753         0.672119
# max          17.439260       10.314554         8.802935         6.501488
#
#        RHT_SPLICE_MA50  RHT_SPLICE_SLOPE5  RHT_SPLICE_SLOPE10  \
# count    118264.000000      118264.000000       118264.000000
# mean         -0.245023          -0.000024           -0.000016
# std           1.150010           0.629304            0.286450
# min          -4.662357         -15.254524           -5.315780
# 25%          -1.006662          -0.301525           -0.133530
# 50%          -0.256718          -0.012236           -0.007324
# 75%           0.495549           0.273479            0.120649
# max           4.275023          16.087770            5.446262
#
#        RHT_SPLICE_SLOPE20  RHT_SPLICE_SLOPE50  LFT_SPLICE_GRADE  \
# count       118264.000000       118264.000000     118264.000000
# mean            -0.000005            0.000009          0.923688
# std              0.137266            0.051530          0.265498
# min             -1.577719           -0.294523          0.000000
# 25%             -0.069006           -0.031708          1.000000
# 50%             -0.003318           -0.000339          1.000000
# 75%              0.064227            0.031360          1.000000
# max              1.695163            0.294010          1.000000
#
#        MID_SPLICE_GRADE  RHT_SPLICE_GRADE   SPLICE_GRADE
# count     118264.000000     118264.000000  118264.000000
# mean           0.925049          0.918826       0.816318
# std            0.263313          0.273104       0.387226
# min            0.000000          0.000000       0.000000
# 25%            1.000000          1.000000       1.000000
# 50%            1.000000          1.000000       1.000000
# 75%            1.000000          1.000000       1.000000
# max            1.000000          1.000000       1.000000

# %%
df_temp = df[(np.abs(stats.zscore(df)) < 3).all(axis=1)]
df_temp.describe(include = 'all')
# Out:
#          CUT_LENGTH  CONV_WAIT_TIME  LFT_SPLICE_LENGTH  MID_SPLICE_LENGTH  \
# count  77939.000000    77939.000000       77939.000000       77939.000000
# mean    1707.637236       63.639128           6.992726           7.518923
# std        1.745386       80.972726           1.563517           1.345488
# min     1697.865000        0.000000           3.502353           4.900139
# 25%     1706.638000       28.314000           5.837592           6.551029
# 50%     1707.772000       32.056000           6.976631           7.400062
# 75%     1708.808000       55.215000           8.115742           8.434980
# max     1718.597000      674.232000          10.991700          12.920880
#
#        RHT_SPLICE_LENGTH     SPLICE_OK  BP1_S8_L      BP1_S7_L      BP1_S6_L  \
# count       77939.000000  77939.000000   77939.0  77939.000000  77939.000000
# mean            7.241141      0.961162       0.0      0.002352      0.002477
# std             1.590290      0.193210       0.0      0.015299      0.015535
# min             3.508865      0.000000       0.0      0.000000      0.000000
# 25%             6.141924      1.000000       0.0      0.000000      0.000000
# 50%             7.285160      1.000000       0.0      0.000000      0.000000
# 75%             8.336213      1.000000       0.0      0.000000      0.000000
# max            10.996480      1.000000       0.0      0.140000      0.140000
#
#            BP1_S5_L      BP1_S4_L      BP1_S3_L      BP1_S2_L     BP1_S1_ML  \
# count  77939.000000  77939.000000  77939.000000  77939.000000  77939.000000
# mean       0.063039      0.061428      0.062163      0.059289      0.072047
# std        0.036720      0.035959      0.035225      0.034558      0.033944
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.040000      0.040000      0.040000      0.040000      0.050000
# 50%        0.070000      0.060000      0.060000      0.060000      0.070000
# 75%        0.090000      0.090000      0.090000      0.080000      0.100000
# max        0.190000      0.180000      0.180000      0.180000      0.180000
#
#           BP1_S1_MR      BP1_S2_R      BP1_S3_R      BP1_S4_R      BP1_S5_R  \
# count  77939.000000  77939.000000  77939.000000  77939.000000  77939.000000
# mean       0.071885      0.048505      0.049048      0.049278      0.049614
# std        0.033954      0.037346      0.037390      0.037943      0.038688
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.050000      0.010000      0.010000      0.010000      0.010000
# 50%        0.070000      0.050000      0.050000      0.050000      0.050000
# 75%        0.100000      0.080000      0.080000      0.080000      0.080000
# max        0.180000      0.160000      0.170000      0.160000      0.170000
#
#            BP1_S6_R      BP1_S7_R  BP1_S8_R   PART_LENGTH  LFT_SPLICE_DELTA  \
# count  77939.000000  77939.000000   77939.0  77939.000000      77939.000000
# mean       0.001826      0.001221       0.0     40.191534         -0.257274
# std        0.011165      0.008209       0.0     23.914525          1.563517
# min        0.000000      0.000000       0.0      1.000000         -3.747647
# 25%        0.000000      0.000000       0.0     23.000000         -1.412408
# 50%        0.000000      0.000000       0.0     39.000000         -0.273369
# 75%        0.000000      0.000000       0.0     55.000000          0.865742
# max        0.100000      0.080000       0.0    217.000000          3.741700
#
#        LFT_SPLICE_PREV  LFT_SPLICE_MA5  LFT_SPLICE_MA10  LFT_SPLICE_MA20  \
# count     77939.000000    77939.000000     77939.000000     77939.000000
# mean         -0.339564       -0.365752        -0.377965        -0.397869
# std           1.735422        1.366196         1.273785         1.183469
# min          -7.258683       -5.582584        -5.011328        -4.429797
# 25%          -1.508932       -1.289460        -1.252145        -1.213156
# 50%          -0.372209       -0.385869        -0.406650        -0.440571
# 75%           0.774066        0.544999         0.471362         0.389226
# max           6.295890        4.644972         4.033040         3.553047
#
#        LFT_SPLICE_MA50  LFT_SPLICE_SLOPE5  LFT_SPLICE_SLOPE10  \
# count     77939.000000       77939.000000        77939.000000
# mean         -0.423275           0.005749            0.004752
# std           1.024336           0.450101            0.197972
# min          -3.800676          -1.886136           -0.829066
# 25%          -1.123928          -0.260368           -0.110326
# 50%          -0.461815          -0.000043            0.001067
# 75%           0.235892           0.265086            0.113682
# max           2.846026           1.889696            0.830288
#
#        LFT_SPLICE_SLOPE20  LFT_SPLICE_SLOPE50  MID_SPLICE_DELTA  \
# count        77939.000000        77939.000000      77939.000000
# mean             0.003562            0.001455         -3.931077
# std              0.099573            0.041675          1.345488
# min             -0.381660           -0.141342         -6.549861
# 25%             -0.054993           -0.024897         -4.898971
# 50%              0.001368            0.001614         -4.049938
# 75%              0.059479            0.027984         -3.015020
# max              0.381787            0.141922          1.470880
#
#        MID_SPLICE_PREV  MID_SPLICE_MA5  MID_SPLICE_MA10  MID_SPLICE_MA20  \
# count     77939.000000    77939.000000     77939.000000     77939.000000
# mean         -4.016903       -4.065907        -4.091482        -4.116097
# std           1.459081        1.207916         1.146309         1.086280
# min          -9.999104       -8.600884        -8.222964        -7.760909
# 25%          -4.993903       -4.907191        -4.888378        -4.869641
# 50%          -4.055292       -4.133698        -4.151006        -4.179579
# 75%          -3.020737       -3.246808        -3.318050        -3.384564
# max           1.470880        0.211146        -0.242297        -0.635818
#
#        MID_SPLICE_MA50  MID_SPLICE_SLOPE5  MID_SPLICE_SLOPE10  \
# count     77939.000000       77939.000000        77939.000000
# mean         -4.127353           0.017120            0.010290
# std           0.967715           0.359183            0.151778
# min          -7.299647          -1.623713           -0.690473
# 25%          -4.805890          -0.196608           -0.072801
# 50%          -4.187910           0.011476            0.012688
# 75%          -3.495710           0.229588            0.097735
# max          -1.164805           1.615247            0.690531
#
#        MID_SPLICE_SLOPE20  MID_SPLICE_SLOPE50  RHT_SPLICE_DELTA  \
# count        77939.000000        77939.000000      77939.000000
# mean             0.004842            0.000431         -0.008859
# std              0.076440            0.033926          1.590290
# min             -0.309234           -0.116638         -3.741135
# 25%             -0.034020           -0.020432         -1.108076
# 50%              0.008526            0.001578          0.035160
# 75%              0.048691            0.021627          1.086213
# max              0.309385            0.116769          3.746480
#
#        RHT_SPLICE_PREV  RHT_SPLICE_MA5  RHT_SPLICE_MA10  RHT_SPLICE_MA20  \
# count     77939.000000    77939.000000     77939.000000     77939.000000
# mean         -0.066668       -0.090281        -0.099542        -0.129402
# std           1.770328        1.415374         1.323774         1.228245
# min          -7.164909       -5.641511        -5.088200        -4.511408
# 25%          -1.209954       -1.039496        -1.003014        -0.976394
# 50%          -0.061219       -0.082377        -0.095097        -0.137621
# 75%           1.085199        0.869431         0.801214         0.701800
# max           6.710210        5.062705         4.565181         3.998852
#
#        RHT_SPLICE_MA50  RHT_SPLICE_SLOPE5  RHT_SPLICE_SLOPE10  \
# count     77939.000000       77939.000000        77939.000000
# mean         -0.190109           0.004334            0.003705
# std           1.051002           0.447548            0.203906
# min          -3.687684          -1.875456           -0.851115
# 25%          -0.912431          -0.261446           -0.115162
# 50%          -0.195609          -0.009030           -0.003490
# 75%           0.518079           0.259659            0.111836
# max           3.203676           1.886411            0.859001
#
#        RHT_SPLICE_SLOPE20  RHT_SPLICE_SLOPE50  LFT_SPLICE_GRADE  \
# count        77939.000000        77939.000000           77939.0
# mean             0.005302            0.003423               1.0
# std              0.106844            0.045719               0.0
# min             -0.411677           -0.153242               1.0
# 25%             -0.057113           -0.025715               1.0
# 50%              0.000373            0.002642               1.0
# 75%              0.060854            0.032083               1.0
# max              0.411494            0.154502               1.0
#
#        MID_SPLICE_GRADE  RHT_SPLICE_GRADE  SPLICE_GRADE
# count           77939.0           77939.0       77939.0
# mean                1.0               1.0           1.0
# std                 0.0               0.0           0.0
# min                 1.0               1.0           1.0
# 25%                 1.0               1.0           1.0
# 50%                 1.0               1.0           1.0
# 75%                 1.0               1.0           1.0
# max                 1.0               1.0           1.0

# %%
df_temp = df[(np.abs(stats.zscore(df)) >= 3).any(axis=1)]
df_temp.describe(include = 'all')
# Out:
#          CUT_LENGTH  CONV_WAIT_TIME  LFT_SPLICE_LENGTH  MID_SPLICE_LENGTH  \
# count  40325.000000    40325.000000       40325.000000       40325.000000
# mean    1707.176709      110.018707           6.351145           6.636424
# std       12.245646      318.268503           3.187737           2.613815
# min        0.000000        0.000000         -47.200000         -56.381480
# 25%     1706.058000       29.398000           4.686976           5.212286
# 50%     1707.463000       38.186000           6.460583           6.771427
# 75%     1708.696000       84.162990           8.128983           8.022474
# max     1719.298000    10034.240000          29.686790          26.034800
#
#        RHT_SPLICE_LENGTH     SPLICE_OK      BP1_S8_L      BP1_S7_L  \
# count       40325.000000  40325.000000  40325.000000  40325.000000
# mean            6.548645      0.533763      0.001160      0.033886
# std             3.277350      0.498865      0.004413      0.067333
# min           -44.709190      0.000000      0.000000      0.000000
# 25%             4.792038      0.000000      0.000000      0.000000
# 50%             6.669694      1.000000      0.000000      0.000000
# 75%             8.439249      1.000000      0.000000      0.019113
# max            24.689260      1.000000      0.138328      0.350000
#
#            BP1_S6_L      BP1_S5_L      BP1_S4_L      BP1_S3_L      BP1_S2_L  \
# count  40325.000000  40325.000000  40325.000000  40325.000000  40325.000000
# mean       0.031614      0.074547      0.070122      0.069818      0.067693
# std        0.065497      0.053641      0.049975      0.047557      0.048325
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.040000      0.040000      0.040000      0.040000
# 50%        0.000000      0.070000      0.070000      0.070000      0.070000
# 75%        0.010000      0.100000      0.100000      0.100000      0.100000
# max        0.350000      0.500000      0.800000      0.500000      0.900000
#
#           BP1_S1_ML     BP1_S1_MR      BP1_S2_R      BP1_S3_R      BP1_S4_R  \
# count  40325.000000  40325.000000  40325.000000  40325.000000  40325.000000
# mean       0.082442      0.080946      0.058547      0.058774      0.058823
# std        0.049839      0.043445      0.045811      0.044840      0.046122
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.050000      0.050000      0.010000      0.020000      0.019113
# 50%        0.080000      0.080000      0.060000      0.060000      0.050000
# 75%        0.100000      0.100000      0.090000      0.090000      0.090000
# max        0.900000      2.000000      0.760000      0.760000      0.900000
#
#            BP1_S5_R      BP1_S6_R      BP1_S7_R      BP1_S8_R   PART_LENGTH  \
# count  40325.000000  40325.000000  40325.000000  40325.000000  40325.000000
# mean       0.059049      0.023196      0.018823      0.001232     46.530391
# std        0.047017      0.047889      0.039157      0.004633     93.871936
# min        0.000000      0.000000      0.000000      0.000000      1.000000
# 25%        0.020000      0.000000      0.000000      0.000000     11.000000
# 50%        0.050000      0.000000      0.000000      0.000000     29.000000
# 75%        0.090000      0.019113      0.010000      0.000000     52.000000
# max        1.000000      0.760000      0.250000      0.138328    999.000000
#
#        LFT_SPLICE_DELTA  LFT_SPLICE_PREV  LFT_SPLICE_MA5  LFT_SPLICE_MA10  \
# count      40325.000000     40325.000000    40325.000000     40325.000000
# mean          -0.898855        -0.739965       -0.689315        -0.665680
# std            3.187737         3.038474        2.211028         1.901276
# min          -54.450000       -54.450000      -27.173353       -15.133216
# 25%           -2.563024        -2.247549       -1.897632        -1.817388
# 50%           -0.789417        -0.586384       -0.627077        -0.669667
# 75%            0.878983         0.979125        0.632189         0.509733
# max           22.436790        22.436790       12.431102         8.291490
#
#        LFT_SPLICE_MA20  LFT_SPLICE_MA50  LFT_SPLICE_SLOPE5  \
# count     40325.000000     40325.000000       40325.000000
# mean         -0.627003        -0.577743          -0.011123
# std           1.604826         1.250255           0.882509
# min          -7.947873        -5.769553         -15.350425
# 25%          -1.652784        -1.392930          -0.373360
# 50%          -0.679572        -0.631818          -0.022806
# 75%           0.388651         0.204541           0.313522
# max           5.000289         4.505002          13.639248
#
#        LFT_SPLICE_SLOPE10  LFT_SPLICE_SLOPE20  LFT_SPLICE_SLOPE50  \
# count        40325.000000        40325.000000        40325.000000
# mean            -0.009199           -0.006922           -0.002817
# std              0.386222            0.168248            0.056555
# min             -5.553173           -1.548232           -0.327986
# 25%             -0.176189           -0.090372           -0.035953
# 50%             -0.015780           -0.008697           -0.002382
# 75%              0.139619            0.072655            0.030411
# max              5.848552            1.758048            0.303629
#
#        MID_SPLICE_DELTA  MID_SPLICE_PREV  MID_SPLICE_MA5  MID_SPLICE_MA10  \
# count      40325.000000     40325.000000    40325.000000     40325.000000
# mean          -4.813576        -4.647832       -4.553249        -4.503888
# std            2.613815         2.543236        1.860019         1.596565
# min          -67.831480       -67.831480      -34.943143       -20.376426
# 25%           -6.237714        -5.779262       -5.493367        -5.415294
# 50%           -4.678573        -4.570038       -4.501038        -4.476726
# 75%           -3.427526        -3.328397       -3.524310        -3.567058
# max           14.584800        14.584800        9.431126         6.906962
#
#        MID_SPLICE_MA20  MID_SPLICE_MA50  MID_SPLICE_SLOPE5  \
# count     40325.000000     40325.000000       40325.000000
# mean         -4.456436        -4.435023          -0.033040
# std           1.366807         1.093444           0.787743
# min         -12.748412        -7.913941         -18.788728
# 25%          -5.315044        -5.132162          -0.290715
# 50%          -4.476618        -4.497348          -0.020984
# 75%          -3.641499        -3.786204           0.239211
# max           3.942696         0.200878          17.390204
#
#        MID_SPLICE_SLOPE10  MID_SPLICE_SLOPE20  MID_SPLICE_SLOPE50  \
# count        40325.000000        40325.000000        40325.000000
# mean            -0.019858           -0.009334           -0.000807
# std              0.332335            0.140657            0.047086
# min             -6.500130           -1.864920           -0.292201
# 25%             -0.124070           -0.060080           -0.025921
# 50%             -0.004463            0.000928            0.000993
# 75%              0.102481            0.052265            0.025031
# max              6.415370            1.849446            0.373360
#
#        RHT_SPLICE_DELTA  RHT_SPLICE_PREV  RHT_SPLICE_MA5  RHT_SPLICE_MA10  \
# count      40325.000000     40325.000000    40325.000000     40325.000000
# mean          -0.701355        -0.589750       -0.543972        -0.525949
# std            3.277350         3.115737        2.344351         2.034841
# min          -51.959190       -51.959190      -23.635951       -11.243221
# 25%           -2.457962        -2.144223       -1.856070        -1.791803
# 50%           -0.580306        -0.376839       -0.437301        -0.500424
# 75%            1.189249         1.191565        0.915105         0.750058
# max           17.439260        17.439260       10.314554         8.802935
#
#        RHT_SPLICE_MA20  RHT_SPLICE_MA50  RHT_SPLICE_SLOPE5  \
# count     40325.000000     40325.000000       40325.000000
# mean         -0.468160        -0.351161          -0.008447
# std           1.715100         1.314021           0.879897
# min          -6.939771        -4.662357         -15.254524
# 25%          -1.597663        -1.213335          -0.390697
# 50%          -0.522341        -0.400332          -0.031851
# 75%           0.587791         0.437130           0.315721
# max           6.501488         4.275023          16.087770
#
#        RHT_SPLICE_SLOPE10  RHT_SPLICE_SLOPE20  RHT_SPLICE_SLOPE50  \
# count        40325.000000        40325.000000        40325.000000
# mean            -0.007208           -0.010263           -0.006589
# std              0.400261            0.181758            0.060675
# min             -5.315780           -1.577719           -0.294523
# 25%             -0.184787           -0.101313           -0.044471
# 50%             -0.017730           -0.012535           -0.007431
# 75%              0.143311            0.073421            0.029509
# max              5.446262            1.695163            0.294010
#
#        LFT_SPLICE_GRADE  MID_SPLICE_GRADE  RHT_SPLICE_GRADE  SPLICE_GRADE
# count      40325.000000      40325.000000      40325.000000  40325.000000
# mean           0.776193          0.780186          0.761934      0.461302
# std            0.416799          0.414126          0.425905      0.498506
# min            0.000000          0.000000          0.000000      0.000000
# 25%            1.000000          1.000000          1.000000      0.000000
# 50%            1.000000          1.000000          1.000000      0.000000
# 75%            1.000000          1.000000          1.000000      1.000000
# max            1.000000          1.000000          1.000000      1.000000

# %%
df_temp = df[df['SPLICE_GRADE']==1]
df_temp.describe(include = 'all')
# Out:
#          CUT_LENGTH  CONV_WAIT_TIME  LFT_SPLICE_LENGTH  MID_SPLICE_LENGTH  \
# count  96541.000000    96541.000000       96541.000000       96541.000000
# mean    1707.645827       73.867987           7.008857           7.485192
# std        5.784067      169.376295           1.586647           1.360918
# min        0.000000        0.000000           3.502353           4.900139
# 25%     1706.662000       28.519000           5.836434           6.460873
# 50%     1707.807000       33.404000           6.978223           7.393116
# 75%     1708.854000       59.545000           8.123919           8.341278
# max     1718.597000    10006.660000          10.998210          17.308730
#
#        RHT_SPLICE_LENGTH     SPLICE_OK      BP1_S8_L      BP1_S7_L  \
# count       96541.000000  96541.000000  96541.000000  96541.000000
# mean            7.263412      0.958090      0.000425      0.012480
# std             1.605104      0.200384      0.002733      0.042999
# min             3.504379      0.000000      0.000000      0.000000
# 25%             6.143516      1.000000      0.000000      0.000000
# 50%             7.289935      1.000000      0.000000      0.000000
# 75%             8.434039      1.000000      0.000000      0.000000
# max            10.996480      1.000000      0.138328      0.350000
#
#            BP1_S6_L      BP1_S5_L      BP1_S4_L      BP1_S3_L      BP1_S2_L  \
# count  96541.000000  96541.000000  96541.000000  96541.000000  96541.000000
# mean       0.011723      0.066019      0.063538      0.063892      0.061355
# std        0.041615      0.042957      0.041120      0.039518      0.039873
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.040000      0.040000      0.040000      0.040000
# 50%        0.000000      0.070000      0.060000      0.070000      0.060000
# 75%        0.000000      0.090000      0.090000      0.090000      0.090000
# max        0.350000      0.500000      0.800000      0.500000      0.900000
#
#           BP1_S1_ML     BP1_S1_MR      BP1_S2_R      BP1_S3_R      BP1_S4_R  \
# count  96541.000000  96541.000000  96541.000000  96541.000000  96541.000000
# mean       0.074536      0.074019      0.051305      0.051726      0.051894
# std        0.039168      0.037464      0.040184      0.039884      0.040593
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.050000      0.050000      0.010000      0.010000      0.010000
# 50%        0.080000      0.080000      0.050000      0.050000      0.050000
# 75%        0.100000      0.100000      0.080000      0.080000      0.080000
# max        0.800000      2.000000      0.760000      0.760000      0.760000
#
#            BP1_S5_R      BP1_S6_R      BP1_S7_R      BP1_S8_R   PART_LENGTH  \
# count  96541.000000  96541.000000  96541.000000  96541.000000  96541.000000
# mean       0.052120      0.008461      0.006692      0.000451     43.701008
# std        0.041439      0.029475      0.024261      0.002870     58.506774
# min        0.000000      0.000000      0.000000      0.000000      1.000000
# 25%        0.010000      0.000000      0.000000      0.000000     20.000000
# 50%        0.050000      0.000000      0.000000      0.000000     38.000000
# 75%        0.080000      0.000000      0.000000      0.000000     55.000000
# max        1.000000      0.760000      0.250000      0.138328    999.000000
#
#        LFT_SPLICE_DELTA  LFT_SPLICE_PREV  LFT_SPLICE_MA5  LFT_SPLICE_MA10  \
# count      96541.000000     96541.000000    96541.000000     96541.000000
# mean          -0.241143        -0.342343       -0.398339        -0.419712
# std            1.586647         1.898928        1.523829         1.403795
# min           -3.747647       -50.600620      -26.602169       -15.133216
# 25%           -1.413566        -1.519640       -1.334176        -1.313655
# 50%           -0.271777        -0.370183       -0.394755        -0.427634
# 75%            0.873919         0.871748        0.571091         0.485681
# max            3.748210        17.125080        8.460806         7.761404
#
#        LFT_SPLICE_MA20  LFT_SPLICE_MA50  LFT_SPLICE_SLOPE5  \
# count     96541.000000     96541.000000       96541.000000
# mean         -0.436448        -0.450785           0.019037
# std           1.271772         1.070049           0.561746
# min          -7.947873        -5.746680         -10.480777
# 25%          -1.271783        -1.169492          -0.267647
# 50%          -0.470114        -0.487096           0.000651
# 75%           0.393231         0.231611           0.277343
# max           5.000289         4.479834          13.639248
#
#        LFT_SPLICE_SLOPE10  LFT_SPLICE_SLOPE20  LFT_SPLICE_SLOPE50  \
# count        96541.000000        96541.000000        96541.000000
# mean             0.009297            0.003745            0.001078
# std              0.249194            0.118082            0.045719
# min             -2.856819           -1.316332           -0.327986
# 25%             -0.115478           -0.058964           -0.026532
# 50%              0.001133            0.000819            0.001207
# 75%              0.119669            0.062373            0.028911
# max              3.904076            1.220067            0.303629
#
#        MID_SPLICE_DELTA  MID_SPLICE_PREV  MID_SPLICE_MA5  MID_SPLICE_MA10  \
# count      96541.000000     96541.000000    96541.000000     96541.000000
# mean          -3.964808        -4.064247       -4.131385        -4.156223
# std            1.360918         1.564129        1.328840         1.243132
# min           -6.549861       -55.010310      -33.006328       -20.189153
# 25%           -4.989127        -5.089993       -4.968289        -4.951748
# 50%           -4.056884        -4.115782       -4.178356        -4.200831
# 75%           -3.108722        -3.112485       -3.301017        -3.367180
# max            5.858730        13.450100        8.429302         6.906962
#
#        MID_SPLICE_MA20  MID_SPLICE_MA50  MID_SPLICE_SLOPE5  \
# count     96541.000000     96541.000000       96541.000000
# mean         -4.173120        -4.182038           0.024539
# std           1.148955         1.001761           0.459181
# min         -12.112780        -7.913941         -10.440967
# 25%          -4.932451        -4.869247          -0.199184
# 50%          -4.227726        -4.248771           0.011693
# 75%          -3.431339        -3.550471           0.238256
# max           3.942696         0.200878          17.390204
#
#        MID_SPLICE_SLOPE10  MID_SPLICE_SLOPE20  MID_SPLICE_SLOPE50  \
# count        96541.000000        96541.000000        96541.000000
# mean             0.010889            0.003923            0.000588
# std              0.198299            0.093329            0.037284
# min             -2.900466           -1.474087           -0.287755
# 25%             -0.077118           -0.036655           -0.020929
# 50%              0.011767            0.007900            0.001505
# 75%              0.099786            0.049636            0.022244
# max              4.148196            1.025810            0.373360
#
#        RHT_SPLICE_DELTA  RHT_SPLICE_PREV  RHT_SPLICE_MA5  RHT_SPLICE_MA10  \
# count      96541.000000     96541.000000    96541.000000     96541.000000
# mean           0.013412        -0.065131       -0.127492        -0.157481
# std            1.605104         1.928950        1.566537         1.455313
# min           -3.745621       -49.770840      -19.113078       -11.243221
# 25%           -1.106484        -1.211690       -1.083185        -1.083489
# 50%            0.039935        -0.059049       -0.084837        -0.125096
# 75%            1.184039         1.183749        0.888766         0.800780
# max            3.746480        15.357410       10.314554         8.802935
#
#        RHT_SPLICE_MA20  RHT_SPLICE_MA50  RHT_SPLICE_SLOPE5  \
# count     96541.000000     96541.000000       96541.000000
# mean         -0.186293        -0.217260           0.023525
# std           1.322410         1.099624           0.558847
# min          -6.939771        -4.662357         -10.421128
# 25%          -1.059980        -0.950512          -0.270137
# 50%          -0.186643        -0.227701          -0.000680
# 75%           0.686283         0.502153           0.272640
# max           6.225563         4.275023          16.087770
#
#        RHT_SPLICE_SLOPE10  RHT_SPLICE_SLOPE20  RHT_SPLICE_SLOPE50  \
# count        96541.000000        96541.000000        96541.000000
# mean             0.012612            0.006200            0.002055
# std              0.255841            0.125688            0.049141
# min             -3.083710           -1.058709           -0.294523
# 25%             -0.118452           -0.060338           -0.028192
# 50%             -0.001466            0.000228            0.001557
# 75%              0.120589            0.064352            0.032082
# max              3.586528            0.939366            0.294010
#
#        LFT_SPLICE_GRADE  MID_SPLICE_GRADE  RHT_SPLICE_GRADE  SPLICE_GRADE
# count           96541.0           96541.0           96541.0       96541.0
# mean                1.0               1.0               1.0           1.0
# std                 0.0               0.0               0.0           0.0
# min                 1.0               1.0               1.0           1.0
# 25%                 1.0               1.0               1.0           1.0
# 50%                 1.0               1.0               1.0           1.0
# 75%                 1.0               1.0               1.0           1.0
# max                 1.0               1.0               1.0           1.0

# %% [raw]
# CUT_LENGTH < 1650 can probably be removed
# Log of CONV_WAIT_TIME may need to be taken. CONV_WAIT_TIME > 1000 can be probably removed
# BP1_S8_L, BP1_S7_L, BP1_S6_L may be ignored
# BP1_S8_R, BP1_S7_R, BP1_S6_R may be ignored too
# It might make sense to include MA and slope for pressure values rather than prev splice length

# %%
column = 'LFT_SPLICE_SLOPE20'
sns.distplot(df_temp[column], fit=norm);
fig = plt.figure()
res = stats.probplot(df_temp[column], plot=plt)

# %%
# df[df['CUT_LENGTH'] < 1650]['SPLICE_GRADE'].value_counts()
 df[df['CONV_WAIT_TIME'] > 1000]['SPLICE_GRADE'].value_counts()
# Out:
# 1    294
# 0    179
# Name: SPLICE_GRADE, dtype: int64

# %%
# df_temp = df
# print(df_temp.shape)
# # Take log of CONV_WAIT_TIME
# df_temp['CONV_WAIT_TIME_LOG'] = np.log(df_temp['CONV_WAIT_TIME'])
# # Remove infinity values after taking log
# df_temp = df_temp.replace([np.inf, -np.inf], np.nan).dropna(subset=["CONV_WAIT_TIME_LOG"], how="all")
# print(df_temp.shape)

# df_temp = df_temp[df_temp['CONV_WAIT_TIME'] < 1000]
df_temp = df[df['CONV_WAIT_TIME'] < 1000]

column = 'CONV_WAIT_TIME_LOG'
sns.distplot(df_temp[column], fit=norm);
fig = plt.figure()
res = stats.probplot(df_temp[column], plot=plt)
# Out:
# (118264, 57)
# C:\Users\SajidPatel\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
# (118191, 58)

# %%
df = df.drop(['SPLICE_OK', 'SPLICE_GRADE', 'MID_SPLICE_GRADE', 'LFT_SPLICE_GRADE', # 'RHT_SPLICE_GRADE', 
              'LFT_SPLICE_LENGTH', 'MID_SPLICE_LENGTH', 'RHT_SPLICE_LENGTH', 
              'LFT_SPLICE_DELTA', 'MID_SPLICE_DELTA', 'RHT_SPLICE_DELTA',              
              'LFT_SPLICE_MA5', 'LFT_SPLICE_MA10', 'LFT_SPLICE_MA20', 'LFT_SPLICE_MA50', 
              'LFT_SPLICE_SLOPE5', 'LFT_SPLICE_SLOPE10', 'LFT_SPLICE_SLOPE20', 'LFT_SPLICE_SLOPE50', 
              'MID_SPLICE_MA5', 'MID_SPLICE_MA10', 'MID_SPLICE_MA20', 'MID_SPLICE_MA50', 
              'MID_SPLICE_SLOPE5', 'MID_SPLICE_SLOPE10', 'MID_SPLICE_SLOPE20', 'MID_SPLICE_SLOPE50',  
              'RHT_SPLICE_MA5', 'RHT_SPLICE_MA10', 'RHT_SPLICE_MA20',  'RHT_SPLICE_MA50', 
              'RHT_SPLICE_SLOPE5', 'RHT_SPLICE_SLOPE10',  'RHT_SPLICE_SLOPE20', 'RHT_SPLICE_SLOPE50',
              'LFT_SPLICE_PREV', 'MID_SPLICE_PREV', 'RHT_SPLICE_PREV',
               'BP1_S8_L', 'BP1_S7_L', 'BP1_S6_L', 'BP1_S6_R', 'BP1_S7_R', 'BP1_S8_R'
             ], axis=1)

print(df.columns)

for col in df.columns:
    if len(df[col].unique()) == 1:
        df = df.drop(col,inplace=True,axis=1)
        
# print(df.columns)
# df['SPLICE_GRADE'].head

# %% [markdown]
# Check the columns in the data

# %%
print(df.shape)
df = df.drop_duplicates()
print(df.shape)

# %%
print(df.shape)
df = df.drop_duplicates(subset=['CUT_LENGTH', 'CONV_WAIT_TIME', #'BP1_S8_L', 'BP1_S7_L', 'BP1_S6_L', 
                                'BP1_S5_L', 
                                'BP1_S4_L', 'BP1_S3_L', 'BP1_S2_L', 'BP1_S1_ML', 'BP1_S1_MR', 'BP1_S2_R', 
                                'BP1_S3_R', 'BP1_S4_R', 'BP1_S5_R', #'BP1_S6_R', 'BP1_S7_R', 'BP1_S8_R'
                               ])
# df = df.drop_duplicates()
print(df.shape)
# df.head

# %%
# Variance of the columns - can drop columns based on the variance
df.std() > 0.04
# df.loc[:, df.std() > .02]

# %%
# Count non-zero values
df.astype(bool).sum(axis=0)

# %%
# df[df['CUT_LENGTH'] < 1000]['SPLICE_GRADE'].value_counts
# pd.DataFrame({'count' : df.groupby(['SPLICE_GRADE'])['CUT_LENGTH'].size()}).reset_index()
temp = df.loc[df['CUT_LENGTH'] < 1700]['SPLICE_GRADE']
temp.value_counts()
# temp

# %%
# scaler = MinMaxScaler()
# mycols = ['CUT_LENGTH', 'CONV_WAIT_TIME', #'BP1_S8_L', 'BP1_S7_L', 'BP1_S6_L', 
#           'BP1_S5_L', 'BP1_S4_L', 'BP1_S3_L', 
#           'BP1_S2_L', 'BP1_S1_ML', 'BP1_S1_MR', 'BP1_S2_R', 'BP1_S3_R', 'BP1_S4_R', 'BP1_S5_R', #'BP1_S6_R',
#           #'BP1_S7_R', 'BP1_S8_R', 
#           'PART_LENGTH' #, 'LFT_SPLICE_PREV', 'MID_SPLICE_PREV', 'RHT_SPLICE_PREV'
#          ]
# df[mycols] = scaler.fit_transform(df[mycols])

# %%
# df.std() > 0.04

# %%
# PCA - todo this one and other few

# from sklearn.decomposition import PCA
# X = df.drop(['RHT_SPLICE_GRADE'], axis=1)
# pca = PCA()
# X_r = pca.fit(X).transform(X)

# %%
from imblearn.over_sampling import SMOTE

X = df.drop(['RHT_SPLICE_GRADE'], axis=1)
y = df['RHT_SPLICE_GRADE'].astype('int')

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=7)
X_train, x2, y_train, y2 = train_test_split(X, y, test_size=0.25, stratify=df['RHT_SPLICE_GRADE'])

print("Number transactions X_train dataset: ", X_train.shape)
print("Number transactions y_train dataset: ", y_train.shape)
print("Number transactions X_test dataset: ", x2.shape)
print("Number transactions y_test dataset: ", y2.shape)

print("Before OverSampling, counts of label '1': {}".format(sum(y_train==1)))
print("Before OverSampling, counts of label '0': {} \n".format(sum(y_train==0)))

sm = SMOTE(random_state=2)
x1, y1 = sm.fit_sample(X_train, y_train.ravel())

print('After OverSampling, the shape of train_X: {}'.format(x1.shape))
print('After OverSampling, the shape of train_y: {} \n'.format(y1.shape))

print("After OverSampling, counts of label '1': {}".format(sum(y1==1)))
print("After OverSampling, counts of label '0': {}".format(sum(y1==0)))

print("Test data, counts of label '1': {}".format(sum(y2==1)))
print("Test data, counts of label '0': {}".format(sum(y2==0)))

# x2, y2 = df_test.drop('RHT_SPLICE_GRADE',axis=1), df_test['RHT_SPLICE_GRADE'].astype('int')

# %%
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()*100).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
print(missing_data.head(10))
df = df.dropna()

# %%
# def numericSG(row):
#     if row['SPLICE_GRADE'] == 'Bad':
#         return 0
#     if row['SPLICE_GRADE'] == 'OK' :
#         return 1
#     return 2

# def inverse(x):
#     if x==0: 
#         return 0
#     return 1/x

# %%
# df_train, df_test = train_test_split(df, test_size=0.25, stratify=df['RHT_SPLICE_GRADE'])

# x1, y1 = df_train.drop('RHT_SPLICE_GRADE',axis=1), df_train['RHT_SPLICE_GRADE'].astype('int')
# x2, y2 = df_test.drop('RHT_SPLICE_GRADE',axis=1), df_test['RHT_SPLICE_GRADE'].astype('int')

# print(x1.columns)

# %%
rfc.fit(x1,y1)
y2_RFC_model = rfc.predict(x2)
print("RandomForestClassifier Accuracy :", accuracy_score(y2, y2_RFC_model))
importances2 = rfc.feature_importances_
std2 = np.std([tree.feature_importances_ for tree in rfc.estimators_], axis=0)
indices2 = np.argsort(importances2)[::-1]

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
#         print("Normalized confusion matrix")
#     else:
#         print('Confusion matrix, without normalization')

#     print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in it.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
target_names = ['Bad', 'Good']
class_names = target_names

# %%
# Compute confusion matrix
cnf_matrix = confusion_matrix(y2, y2_RFC_model)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='RFC Confusion matrix, without normalization')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='RFC Normalized confusion matrix')

plt.show();

# %%
print(" *********** RandomForestClassifier *********** ")
print(classification_report(y2, y2_RFC_model, target_names=target_names, sample_weight=None, digits=4))

# %%
# import numpy as np
# from scipy import interp
# import matplotlib.pyplot as plt

# from sklearn import svm, datasets
# from sklearn.metrics import roc_curve, auc
# from sklearn.model_selection import StratifiedKFold

# # Run classifier with cross-validation and plot ROC curves
# cv = StratifiedKFold(n_splits=6)
# classifier = svm.SVC(probability=True, random_state=7)

# tprs = []
# aucs = []
# mean_fpr = np.linspace(0, 1, 100)

# X = df.drop(['SPLICE_GRADE'], axis=1)
# y = df['SPLICE_GRADE'].astype('int')

# i = 0
# for train, test in cv.split(X, y):
#     probas_ = classifier.fit(X[train], y[train]).predict_proba(X[test])
#     # Compute ROC curve and area the curve
#     fpr, tpr, thresholds = roc_curve(y[test], probas_[:, 1])
#     tprs.append(interp(mean_fpr, fpr, tpr))
#     tprs[-1][0] = 0.0
#     roc_auc = auc(fpr, tpr)
#     aucs.append(roc_auc)
#     plt.plot(fpr, tpr, lw=1, alpha=0.3,
#              label='ROC fold %d (AUC = %0.2f)' % (i, roc_auc))

#     i += 1
# plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
#          label='Chance', alpha=.8)

# %%
# from sklearn.externals import joblib
# joblib.dump(rfc, 'rfc_bp1_02_great.pkl', compress=9)

# %%
# from sklearn2pmml import sklearn2pmml
# from sklearn2pmml import make_pmml_pipeline

# pipeline = make_pmml_pipeline(rfc)
# sklearn2pmml(pipeline, "rfc_bp1_rht.pmml", with_repr = True)

# %%
# https://www.marcoaltini.com/blog/dealing-with-imbalanced-data-undersampling-oversampling-and-proper-cross-validation
