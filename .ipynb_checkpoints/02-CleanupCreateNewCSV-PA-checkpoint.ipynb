# %% [markdown]
# Import python libraries required for the script

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import warnings

from mpl_toolkits.mplot3d import Axes3D
from scipy import stats
from scipy.stats import norm
from scipy.stats import linregress
from sklearn.preprocessing import StandardScaler
from numpy.polynomial import polynomial as npp

warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# Read the CSV files

# %%
df = pd.read_csv('VMI_Data_PA_V02_AK6_090118_032619_mod01.csv')

# Sampling after cleanup
# df_sample = df.sample(10000)

# %% [markdown]
# Check the columns in the data

# %%
print(df.columns)
# Out:
# Index(['MACHINE_ID', 'DATE_TIME_STAMP', 'GT_BARCODE', 'TIRE_TYPE',
#        'CUT_LENGTH', 'CONV_WAIT_TIME', 'LFT_SPLICE_LENGTH',
#        'MID_SPLICE_LENGTH', 'RHT_SPLICE_LENGTH', 'SPLICE_OK', 'PA_S8_L',
#        'PA_S7_L', 'PA_S6_L', 'PA_S5_L', 'PA_S4_L', 'PA_S3_L', 'PA_S2_L',
#        'PA_S1_ML', 'PA_S1_MR', 'PA_S2_R', 'PA_S3_R', 'PA_S4_R', 'PA_S5_R',
#        'PA_S6_R', 'PA_S7_R', 'PA_S8_R', 'PA_PART', 'PA_BARCODE', 'PART_LENGTH',
#        'PA_BUILD_DATE', 'PA_MACHINEID', 'LFT_SPLICE_DELTA', 'LFT_SPLICE_PREV',
#        'LFT_SPLICE_MA5', 'LFT_SPLICE_MA10', 'LFT_SPLICE_MA20',
#        'LFT_SPLICE_MA50', 'LFT_SPLICE_SLOPE5', 'LFT_SPLICE_SLOPE10',
#        'LFT_SPLICE_SLOPE20', 'LFT_SPLICE_SLOPE50', 'MID_SPLICE_DELTA',
#        'MID_SPLICE_PREV', 'MID_SPLICE_MA5', 'MID_SPLICE_MA10',
#        'MID_SPLICE_MA20', 'MID_SPLICE_MA50', 'MID_SPLICE_SLOPE5',
#        'MID_SPLICE_SLOPE10', 'MID_SPLICE_SLOPE20', 'MID_SPLICE_SLOPE50',
#        'RHT_SPLICE_DELTA', 'RHT_SPLICE_PREV', 'RHT_SPLICE_MA5',
#        'RHT_SPLICE_MA10', 'RHT_SPLICE_MA20', 'RHT_SPLICE_MA50',
#        'RHT_SPLICE_SLOPE5', 'RHT_SPLICE_SLOPE10', 'RHT_SPLICE_SLOPE20',
#        'RHT_SPLICE_SLOPE50', 'LFT_SPLICE_GRADE', 'MID_SPLICE_GRADE',
#        'RHT_SPLICE_GRADE', 'SPLICE_GRADE'],
#       dtype='object')

# %%
# df = df.drop('SPLICE_LIMIT_LOW',1)
# df = df.drop('SPLICE_LIMIT_HIGH',1)
# df = df.drop('ID',1)

# %% [markdown]
# Deleting unwanted columns to conserve memory used for the script

# %%
df = df.drop('MACHINE_ID',1)
# df = df.drop('DATE_TIME_STAMP',1)
df = df.drop('GT_BARCODE',1)
df = df.drop('TIRE_TYPE',1)
df = df.drop('PA_PART',1)
# df = df.drop('PA_BARCODE',1)
df = df.drop('PA_BUILD_DATE',1)
# df = df.drop('PA_MACHINEID',1)

# %%
df.dtypes
# Out:
# CUT_LENGTH            float64
# CONV_WAIT_TIME        float64
# LFT_SPLICE_LENGTH     float64
# MID_SPLICE_LENGTH     float64
# RHT_SPLICE_LENGTH     float64
# SPLICE_OK               int64
# PA_S8_L               float64
# PA_S7_L               float64
# PA_S6_L               float64
# PA_S5_L               float64
# PA_S4_L               float64
# PA_S3_L               float64
# PA_S2_L               float64
# PA_S1_ML              float64
# PA_S1_MR              float64
# PA_S2_R               float64
# PA_S3_R               float64
# PA_S4_R               float64
# PA_S5_R               float64
# PA_S6_R               float64
# PA_S7_R               float64
# PA_S8_R               float64
# PART_LENGTH             int64
# LFT_SPLICE_DELTA      float64
# LFT_SPLICE_PREV       float64
# LFT_SPLICE_MA5        float64
# LFT_SPLICE_MA10       float64
# LFT_SPLICE_MA20       float64
# LFT_SPLICE_MA50       float64
# LFT_SPLICE_SLOPE5     float64
# LFT_SPLICE_SLOPE10    float64
# LFT_SPLICE_SLOPE20    float64
# LFT_SPLICE_SLOPE50    float64
# MID_SPLICE_DELTA      float64
# MID_SPLICE_PREV       float64
# MID_SPLICE_MA5        float64
# MID_SPLICE_MA10       float64
# MID_SPLICE_MA20       float64
# MID_SPLICE_MA50       float64
# MID_SPLICE_SLOPE5     float64
# MID_SPLICE_SLOPE10    float64
# MID_SPLICE_SLOPE20    float64
# MID_SPLICE_SLOPE50    float64
# RHT_SPLICE_DELTA      float64
# RHT_SPLICE_PREV       float64
# RHT_SPLICE_MA5        float64
# RHT_SPLICE_MA10       float64
# RHT_SPLICE_MA20       float64
# RHT_SPLICE_MA50       float64
# RHT_SPLICE_SLOPE5     float64
# RHT_SPLICE_SLOPE10    float64
# RHT_SPLICE_SLOPE20    float64
# RHT_SPLICE_SLOPE50    float64
# LFT_SPLICE_GRADE        int64
# MID_SPLICE_GRADE        int64
# RHT_SPLICE_GRADE        int64
# SPLICE_GRADE            int64
# dtype: object

# %%
df.describe()
# Out:
#           CUT_LENGTH  CONV_WAIT_TIME  LFT_SPLICE_LENGTH  MID_SPLICE_LENGTH  \
# count  135015.000000   135015.000000      135015.000000      135015.000000
# mean     1707.333466       40.327264           7.327520          17.052125
# std         3.795010      177.038352           2.156290           5.695805
# min      1089.281000        4.799000         -13.438310         -34.990450
# 25%      1706.495000        5.112000           5.959708          15.702260
# 50%      1707.528000        6.741000           7.304143          16.429900
# 75%      1708.468000       21.532000           8.653329          17.154220
# max      1943.112000    10000.010000          34.460590          88.384550
#
#        RHT_SPLICE_LENGTH      SPLICE_OK        PA_S8_L        PA_S7_L  \
# count      135015.000000  135015.000000  135015.000000  135015.000000
# mean            7.121214       0.000252       0.006956       0.007849
# std             2.135112       0.015867       0.029990       0.032908
# min           -58.815900       0.000000       0.000000       0.000000
# 25%             5.753005       0.000000       0.000000       0.000000
# 50%             6.996248       0.000000       0.000000       0.000000
# 75%             8.342842       0.000000       0.000000       0.000000
# max            47.205240       1.000000       0.200000       0.500000
#
#              PA_S6_L        PA_S5_L  ...  RHT_SPLICE_MA20  RHT_SPLICE_MA50  \
# count  135015.000000  135015.000000  ...    135015.000000    135015.000000
# mean        0.031361       0.037445  ...        -0.128437        -0.127895
# std         0.035590       0.110960  ...         1.502909         1.417717
# min         0.000000       0.000000  ...        -6.346968        -4.770777
# 25%         0.020000       0.010000  ...        -1.140245        -1.085994
# 50%         0.020000       0.010000  ...        -0.290048        -0.319198
# 75%         0.040000       0.030000  ...         0.702985         0.618251
# max         0.690000       1.000000  ...        10.279938         7.978172
#
#        RHT_SPLICE_SLOPE5  RHT_SPLICE_SLOPE10  RHT_SPLICE_SLOPE20  \
# count      135015.000000       135015.000000       135015.000000
# mean           -0.000024           -0.000031           -0.000038
# std             0.511461            0.201381            0.087826
# min           -13.110264           -3.294169           -0.885462
# 25%            -0.299612           -0.120430           -0.053749
# 50%            -0.010479           -0.005664           -0.002051
# 75%             0.281310            0.116274            0.052606
# max            12.788060            3.404250            0.847566
#
#        RHT_SPLICE_SLOPE50  LFT_SPLICE_GRADE  MID_SPLICE_GRADE  \
# count       135015.000000     135015.000000     135015.000000
# mean            -0.000036          0.922453          0.903307
# std              0.030147          0.267458          0.295540
# min             -0.235768          0.000000          0.000000
# 25%             -0.017525          1.000000          1.000000
# 50%              0.000582          1.000000          1.000000
# 75%              0.018258          1.000000          1.000000
# max              0.188034          1.000000          1.000000
#
#        RHT_SPLICE_GRADE   SPLICE_GRADE
# count     135015.000000  135015.000000
# mean           0.927445       0.798719
# std            0.259405       0.400959
# min            0.000000       0.000000
# 25%            1.000000       1.000000
# 50%            1.000000       1.000000
# 75%            1.000000       1.000000
# max            1.000000       1.000000
#
# [8 rows x 57 columns]

# %% [markdown]
# Check missing data

# %%
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()*100).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
print(missing_data.head(20))
df = df.dropna()
# Out:
#                   Total  Percent
# SPLICE_GRADE          0      0.0
# LFT_SPLICE_MA20       0      0.0
# LFT_SPLICE_MA5        0      0.0
# LFT_SPLICE_PREV       0      0.0
# LFT_SPLICE_DELTA      0      0.0
# PART_LENGTH           0      0.0
# PA_S8_R               0      0.0
# PA_S7_R               0      0.0
# PA_S6_R               0      0.0
# PA_S5_R               0      0.0
# PA_S4_R               0      0.0
# PA_S3_R               0      0.0
# PA_S2_R               0      0.0
# PA_S1_MR              0      0.0
# PA_S1_ML              0      0.0
# PA_S2_L               0      0.0
# PA_S3_L               0      0.0
# PA_S4_L               0      0.0
# PA_S5_L               0      0.0
# PA_S6_L               0      0.0

# %%
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()*100).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
print(missing_data.head(20))
# Out:
#                   Total  Percent
# SPLICE_GRADE          0      0.0
# LFT_SPLICE_MA20       0      0.0
# LFT_SPLICE_MA5        0      0.0
# LFT_SPLICE_PREV       0      0.0
# LFT_SPLICE_DELTA      0      0.0
# PART_LENGTH           0      0.0
# PA_S8_R               0      0.0
# PA_S7_R               0      0.0
# PA_S6_R               0      0.0
# PA_S5_R               0      0.0
# PA_S4_R               0      0.0
# PA_S3_R               0      0.0
# PA_S2_R               0      0.0
# PA_S1_MR              0      0.0
# PA_S1_ML              0      0.0
# PA_S2_L               0      0.0
# PA_S3_L               0      0.0
# PA_S4_L               0      0.0
# PA_S5_L               0      0.0
# PA_S6_L               0      0.0

# %%
# deleting points
# df.sort_values(by = 'CUT_LENGTH', ascending = False)[:2]
# #df = df.drop(df[df['CUT_LENGTH'] > 1720].index)
# df = df.drop(df[df['CUT_LENGTH'] < 1680].index)

# df.sort_index(inplace=True)

# %%
#histogram and normal probability plot
sns.distplot(df['CUT_LENGTH'], fit=norm);
fig = plt.figure()
res = stats.probplot(df['CUT_LENGTH'], plot=plt)

# %%
#histogram and normal probability plot
sns.distplot(df['LFT_SPLICE_DELTA'], fit=norm);
fig = plt.figure()
res = stats.probplot(df['LFT_SPLICE_DELTA'], plot=plt)

# %%
# # deleting points
# df.sort_values(by = 'MID_SPLICE_DELTA', ascending = False)[:2]
# df = df.drop(df[df['MID_SPLICE_DELTA'] < -20].index)

# df.sort_index(inplace=True)

# %%
#histogram and normal probability plot
sns.distplot(df['MID_SPLICE_DELTA'], fit=norm);
fig = plt.figure()
res = stats.probplot(df['MID_SPLICE_DELTA'], plot=plt)

# %%
# # deleting points
# df.sort_values(by = 'RHT_SPLICE_DELTA', ascending = False)[:2]
# df = df.drop(df[df['RHT_SPLICE_DELTA'] < -20].index)

# df.sort_index(inplace=True)

# %%
#histogram and normal probability plot
sns.distplot(df['RHT_SPLICE_DELTA'], fit=norm);
fig = plt.figure()
res = stats.probplot(df['RHT_SPLICE_DELTA'], plot=plt)

# %%
# # # deleting points
# # df.sort_values(by = 'CONV_WAIT_TIME', ascending = False)[:2]
# # df = df.drop(df[df['CONV_WAIT_TIME'] > 1000].index)

# # df.sort_index(inplace=True)

# df['CONV_WAIT_TIME'] = df['CONV_WAIT_TIME'] + 1

# # applying log transformation
# df['CONV_WAIT_TIME'] = np.log(df['CONV_WAIT_TIME'])

# %%
#histogram and normal probability plot
sns.distplot(df['CONV_WAIT_TIME'], fit=norm);
fig = plt.figure()
res = stats.probplot(df['CONV_WAIT_TIME'], plot=plt)

# %%
df_sample = df.sample(10000)

# %%
def outliers_z_score(ys):
    threshold = 3

    mean_y = np.mean(ys)
    stdev_y = np.std(ys)
    z_scores = [(y - mean_y) / stdev_y for y in ys]
    return np.where(np.abs(z_scores) > threshold)

# %%
def outliers_modified_z_score(ys):
    threshold = 3.5

    median_y = np.median(ys)
    median_absolute_deviation_y = np.median([np.abs(y - median_y) for y in ys])
    modified_z_scores = [0.6745 * (y - median_y) / median_absolute_deviation_y
                         for y in ys]
    return np.where(np.abs(modified_z_scores) > threshold)

# %%
def outliers_iqr(ys):
    quartile_1, quartile_3 = np.percentile(ys, [25, 75])
    iqr = quartile_3 - quartile_1
    lower_bound = quartile_1 - (iqr * 1.5)
    upper_bound = quartile_3 + (iqr * 1.5)
    return np.where((ys > upper_bound) | (ys < lower_bound))

# %%
# todo
a = outliers_iqr(df['CUT_LENGTH'])
a
# Out:
# (array([  2204,   2206,   2212, ..., 132240, 132813, 134736], dtype=int64),)

# %%
def myZscore(x):
    if not np.issubdtype(x.dtype, np.number):
        return 5    
    print(x.dtype)
    return np.abs(x - x.mean()) / x.std()

# %%
# numeric_cols = df.select_dtypes(include=[np.number]).columns
# print(numeric_cols)
# df_temp = df[np.abs(stats.zscore(df) < 4).all(axis=1)]
# df[df.apply(lambda x: np.abs(x - x.mean()) / x.std() < 3).all(axis=1)]
# df_temp = df[df[numeric_cols].apply(lambda x: np.abs(x - x.mean()) / x.std() < 3).all(axis=1)]
# print(df_temp.shape)

# %%
#box plot
var = 'PA_S8_L'
data = pd.concat([df['LFT_SPLICE_DELTA'], df[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="LFT_SPLICE_DELTA", data=data)
# fig.axis(ymin=10, ymax=25);

# %%
#box plot
var = 'PA_S8_L'
data = pd.concat([df['MID_SPLICE_DELTA'], df[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="MID_SPLICE_DELTA", data=data) # todo showfliers=False
# fig.axis(ymin=10, ymax=25);

# %%
#box plot
var = 'PA_S8_L'
data = pd.concat([df['RHT_SPLICE_DELTA'], df[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="RHT_SPLICE_DELTA", data=data) # todo , showfliers=False)
# fig.axis(ymin=10, ymax=25);

# %%
#skewness and kurtosis
print("Skewness: %f" % df['CUT_LENGTH'].skew())
print("Kurtosis: %f" % df['CUT_LENGTH'].kurt())
# Out:
# Skewness: -75.655359
# Kurtosis: 9097.961373

# %%
#skewness and kurtosis
print("Skewness: %f" % df['CONV_WAIT_TIME'].skew())
print("Kurtosis: %f" % df['CONV_WAIT_TIME'].kurt())
# Out:
# Skewness: 30.690286
# Kurtosis: 1409.250223

# %%
#scatter plot
ax = sns.scatterplot(x="CONV_WAIT_TIME", y="CUT_LENGTH", hue="SPLICE_GRADE", data=df)

# %%
#scatter plot
ax = sns.scatterplot(x="PA_S8_L", y="MID_SPLICE_LENGTH", hue="SPLICE_GRADE", data=df)

# %%
#correlation map
corrmat = df.corr()
f,ax = plt.subplots(figsize=(25, 25))
sns.set(font_scale=0.9)
sns.heatmap(corrmat, annot=True, linewidths=.2, fmt= '.1f',ax=ax)
plt.show()

# %%
# correlation matrix
k = 15 #number of variables for heatmap
cols = corrmat.nlargest(k, 'SPLICE_OK')['SPLICE_OK'].index
cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale=0.9)
f, ax = plt.subplots(figsize=(20, 20))
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %%
data = []
for f in df.columns:
    # Defining the role
    if f == 'SPLICE_OK':
        role = 'target'
    elif f in ['ID','MACHINE_ID','DATE_TIME_STAMP','GT_BARCODE','TIRE_TYPE','SPLICE_LIMIT_LOW',
               'SPLICE_LIMIT_HIGH','BP1_PART','BP1_BARCODE', 'BP1_BUILD_DATE','BP1_MACHINEID']:
        role = 'id'
    else:
        role = 'input'
         
    # Defining the level
    if f == 'SPLICE_OK':
        opType = 'binary'
    elif f == 'DATE_TIME_STAMP':
        opType = 'timestamp'
    elif df[f].dtype == object:
        opType = 'nominal'
    elif df[f].dtype == bool:
        opType = 'binary'
    elif df[f].dtype == int:
        opType = 'interval'
    elif df[f].dtype == float:
        opType = 'interval'
    else :
        opType = 'interval'
        
    # Initialize keep to True for all variables except for id
    keep = True
    if f in ['ID','MACHINE_ID','DATE_TIME_STAMP','GT_BARCODE','TIRE_TYPE','SPLICE_LIMIT_LOW',
             'SPLICE_LIMIT_HIGH','BP1_PART','BP1_BARCODE', 'BP1_BUILD_DATE','BP1_MACHINEID']:
        keep = False
    
    # Defining the data type 
    dtype = df[f].dtype
    
    # Creating a Dict that contains all the metadata for the variable
    f_dict = {
        'varname': f,
        'role': role,
        'level': opType,
        'keep': keep,
        'dtype': dtype
    }
    data.append(f_dict)
    
meta = pd.DataFrame(data, columns=['varname', 'role', 'level', 'keep', 'dtype'])
meta.set_index('varname', inplace=True)

# %%
meta
# Out:
#                       role     level  keep    dtype
# varname
# CUT_LENGTH           input  interval  True  float64
# CONV_WAIT_TIME       input  interval  True  float64
# LFT_SPLICE_LENGTH    input  interval  True  float64
# MID_SPLICE_LENGTH    input  interval  True  float64
# RHT_SPLICE_LENGTH    input  interval  True  float64
# SPLICE_OK           target    binary  True    int64
# PA_S8_L              input  interval  True  float64
# PA_S7_L              input  interval  True  float64
# PA_S6_L              input  interval  True  float64
# PA_S5_L              input  interval  True  float64
# PA_S4_L              input  interval  True  float64
# PA_S3_L              input  interval  True  float64
# PA_S2_L              input  interval  True  float64
# PA_S1_ML             input  interval  True  float64
# PA_S1_MR             input  interval  True  float64
# PA_S2_R              input  interval  True  float64
# PA_S3_R              input  interval  True  float64
# PA_S4_R              input  interval  True  float64
# PA_S5_R              input  interval  True  float64
# PA_S6_R              input  interval  True  float64
# PA_S7_R              input  interval  True  float64
# PA_S8_R              input  interval  True  float64
# PART_LENGTH          input  interval  True    int64
# LFT_SPLICE_DELTA     input  interval  True  float64
# LFT_SPLICE_PREV      input  interval  True  float64
# LFT_SPLICE_MA5       input  interval  True  float64
# LFT_SPLICE_MA10      input  interval  True  float64
# LFT_SPLICE_MA20      input  interval  True  float64
# LFT_SPLICE_MA50      input  interval  True  float64
# LFT_SPLICE_SLOPE5    input  interval  True  float64
# LFT_SPLICE_SLOPE10   input  interval  True  float64
# LFT_SPLICE_SLOPE20   input  interval  True  float64
# LFT_SPLICE_SLOPE50   input  interval  True  float64
# MID_SPLICE_DELTA     input  interval  True  float64
# MID_SPLICE_PREV      input  interval  True  float64
# MID_SPLICE_MA5       input  interval  True  float64
# MID_SPLICE_MA10      input  interval  True  float64
# MID_SPLICE_MA20      input  interval  True  float64
# MID_SPLICE_MA50      input  interval  True  float64
# MID_SPLICE_SLOPE5    input  interval  True  float64
# MID_SPLICE_SLOPE10   input  interval  True  float64
# MID_SPLICE_SLOPE20   input  interval  True  float64
# MID_SPLICE_SLOPE50   input  interval  True  float64
# RHT_SPLICE_DELTA     input  interval  True  float64
# RHT_SPLICE_PREV      input  interval  True  float64
# RHT_SPLICE_MA5       input  interval  True  float64
# RHT_SPLICE_MA10      input  interval  True  float64
# RHT_SPLICE_MA20      input  interval  True  float64
# RHT_SPLICE_MA50      input  interval  True  float64
# RHT_SPLICE_SLOPE5    input  interval  True  float64
# RHT_SPLICE_SLOPE10   input  interval  True  float64
# RHT_SPLICE_SLOPE20   input  interval  True  float64
# RHT_SPLICE_SLOPE50   input  interval  True  float64
# LFT_SPLICE_GRADE     input  interval  True    int64
# MID_SPLICE_GRADE     input  interval  True    int64
# RHT_SPLICE_GRADE     input  interval  True    int64
# SPLICE_GRADE         input  interval  True    int64

# %%
meta[(meta.level == 'interval') & (meta.keep)].index
# Out:
# Index(['CUT_LENGTH', 'CONV_WAIT_TIME', 'LFT_SPLICE_LENGTH',
#        'MID_SPLICE_LENGTH', 'RHT_SPLICE_LENGTH', 'PA_S8_L', 'PA_S7_L',
#        'PA_S6_L', 'PA_S5_L', 'PA_S4_L', 'PA_S3_L', 'PA_S2_L', 'PA_S1_ML',
#        'PA_S1_MR', 'PA_S2_R', 'PA_S3_R', 'PA_S4_R', 'PA_S5_R', 'PA_S6_R',
#        'PA_S7_R', 'PA_S8_R', 'PART_LENGTH', 'LFT_SPLICE_DELTA',
#        'LFT_SPLICE_PREV', 'LFT_SPLICE_MA5', 'LFT_SPLICE_MA10',
#        'LFT_SPLICE_MA20', 'LFT_SPLICE_MA50', 'LFT_SPLICE_SLOPE5',
#        'LFT_SPLICE_SLOPE10', 'LFT_SPLICE_SLOPE20', 'LFT_SPLICE_SLOPE50',
#        'MID_SPLICE_DELTA', 'MID_SPLICE_PREV', 'MID_SPLICE_MA5',
#        'MID_SPLICE_MA10', 'MID_SPLICE_MA20', 'MID_SPLICE_MA50',
#        'MID_SPLICE_SLOPE5', 'MID_SPLICE_SLOPE10', 'MID_SPLICE_SLOPE20',
#        'MID_SPLICE_SLOPE50', 'RHT_SPLICE_DELTA', 'RHT_SPLICE_PREV',
#        'RHT_SPLICE_MA5', 'RHT_SPLICE_MA10', 'RHT_SPLICE_MA20',
#        'RHT_SPLICE_MA50', 'RHT_SPLICE_SLOPE5', 'RHT_SPLICE_SLOPE10',
#        'RHT_SPLICE_SLOPE20', 'RHT_SPLICE_SLOPE50', 'LFT_SPLICE_GRADE',
#        'MID_SPLICE_GRADE', 'RHT_SPLICE_GRADE', 'SPLICE_GRADE'],
#       dtype='object', name='varname')

# %%
pd.DataFrame({'count' : meta.groupby(['role', 'level'])['role'].size()}).reset_index()
# Out:
#      role     level  count
# 0   input  interval     56
# 1  target    binary      1

# %%
v = meta[(meta.level == 'interval') & (meta.keep)].index
df[v].describe()
# Out:
#           CUT_LENGTH  CONV_WAIT_TIME  LFT_SPLICE_LENGTH  MID_SPLICE_LENGTH  \
# count  135015.000000   135015.000000      135015.000000      135015.000000
# mean     1707.333466       40.327264           7.327520          17.052125
# std         3.795010      177.038352           2.156290           5.695805
# min      1089.281000        4.799000         -13.438310         -34.990450
# 25%      1706.495000        5.112000           5.959708          15.702260
# 50%      1707.528000        6.741000           7.304143          16.429900
# 75%      1708.468000       21.532000           8.653329          17.154220
# max      1943.112000    10000.010000          34.460590          88.384550
#
#        RHT_SPLICE_LENGTH        PA_S8_L        PA_S7_L        PA_S6_L  \
# count      135015.000000  135015.000000  135015.000000  135015.000000
# mean            7.121214       0.006956       0.007849       0.031361
# std             2.135112       0.029990       0.032908       0.035590
# min           -58.815900       0.000000       0.000000       0.000000
# 25%             5.753005       0.000000       0.000000       0.020000
# 50%             6.996248       0.000000       0.000000       0.020000
# 75%             8.342842       0.000000       0.000000       0.040000
# max            47.205240       0.200000       0.500000       0.690000
#
#              PA_S5_L        PA_S4_L  ...  RHT_SPLICE_MA20  RHT_SPLICE_MA50  \
# count  135015.000000  135015.000000  ...    135015.000000    135015.000000
# mean        0.037445       0.262118  ...        -0.128437        -0.127895
# std         0.110960       0.149584  ...         1.502909         1.417717
# min         0.000000       0.000000  ...        -6.346968        -4.770777
# 25%         0.010000       0.170000  ...        -1.140245        -1.085994
# 50%         0.010000       0.280000  ...        -0.290048        -0.319198
# 75%         0.030000       0.300000  ...         0.702985         0.618251
# max         1.000000       1.000000  ...        10.279938         7.978172
#
#        RHT_SPLICE_SLOPE5  RHT_SPLICE_SLOPE10  RHT_SPLICE_SLOPE20  \
# count      135015.000000       135015.000000       135015.000000
# mean           -0.000024           -0.000031           -0.000038
# std             0.511461            0.201381            0.087826
# min           -13.110264           -3.294169           -0.885462
# 25%            -0.299612           -0.120430           -0.053749
# 50%            -0.010479           -0.005664           -0.002051
# 75%             0.281310            0.116274            0.052606
# max            12.788060            3.404250            0.847566
#
#        RHT_SPLICE_SLOPE50  LFT_SPLICE_GRADE  MID_SPLICE_GRADE  \
# count       135015.000000     135015.000000     135015.000000
# mean            -0.000036          0.922453          0.903307
# std              0.030147          0.267458          0.295540
# min             -0.235768          0.000000          0.000000
# 25%             -0.017525          1.000000          1.000000
# 50%              0.000582          1.000000          1.000000
# 75%              0.018258          1.000000          1.000000
# max              0.188034          1.000000          1.000000
#
#        RHT_SPLICE_GRADE   SPLICE_GRADE
# count     135015.000000  135015.000000
# mean           0.927445       0.798719
# std            0.259405       0.400959
# min            0.000000       0.000000
# 25%            1.000000       1.000000
# 50%            1.000000       1.000000
# 75%            1.000000       1.000000
# max            1.000000       1.000000
#
# [8 rows x 56 columns]

# %%
v = meta[(meta.level == 'binary') & (meta.keep)].index
df[v].describe()
# Out:
#            SPLICE_OK
# count  135015.000000
# mean        0.000252
# std         0.015867
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %%
#bivariate analysis
ax = sns.scatterplot(x="PA_S2_R", y="LFT_SPLICE_LENGTH", hue="SPLICE_GRADE", data=df)

# %%
# # deleting points
# df.sort_values(by = 'CUT_LENGTH', ascending = False)[:2]
# #df = df.drop(df[df['CUT_LENGTH'] > 1720].index)
# #df = df.drop(df[df['CUT_LENGTH'] < 1690].index)

# df.sort_index(inplace=True)

# %%
#bivariate analysis
ax = sns.scatterplot(x="PA_S2_R", y="MID_SPLICE_DELTA", hue="SPLICE_GRADE", data=df)

# %%
#bivariate analysis saleprice/grlivarea
ax = sns.scatterplot(x="PA_S1_ML", y="MID_SPLICE_DELTA", hue="SPLICE_GRADE", data=df)

# %%
#applying log transformation
# df['CUT_LENGTH_LOG'] = np.log(df['CUT_LENGTH'])

# %%
#transformed histogram and normal probability plot
# sns.distplot(df['CUT_LENGTH_LOG'], fit=norm);
# fig = plt.figure()
# res = stats.probplot(df['CUT_LENGTH_LOG'], plot=plt)

# %%
# df = df.drop('CUT_LENGTH_LOG',1)

# %%
#from bokeh.charts import HeatMap, bins, output_file, show, vplot
#hm1 = HeatMap(autompg, x=bins('mpg'), y=bins('displ'))

df.columns
# Out:
# Index(['CUT_LENGTH', 'CONV_WAIT_TIME', 'LFT_SPLICE_LENGTH',
#        'MID_SPLICE_LENGTH', 'RHT_SPLICE_LENGTH', 'SPLICE_OK', 'PA_S8_L',
#        'PA_S7_L', 'PA_S6_L', 'PA_S5_L', 'PA_S4_L', 'PA_S3_L', 'PA_S2_L',
#        'PA_S1_ML', 'PA_S1_MR', 'PA_S2_R', 'PA_S3_R', 'PA_S4_R', 'PA_S5_R',
#        'PA_S6_R', 'PA_S7_R', 'PA_S8_R', 'PART_LENGTH', 'LFT_SPLICE_DELTA',
#        'LFT_SPLICE_PREV', 'LFT_SPLICE_MA5', 'LFT_SPLICE_MA10',
#        'LFT_SPLICE_MA20', 'LFT_SPLICE_MA50', 'LFT_SPLICE_SLOPE5',
#        'LFT_SPLICE_SLOPE10', 'LFT_SPLICE_SLOPE20', 'LFT_SPLICE_SLOPE50',
#        'MID_SPLICE_DELTA', 'MID_SPLICE_PREV', 'MID_SPLICE_MA5',
#        'MID_SPLICE_MA10', 'MID_SPLICE_MA20', 'MID_SPLICE_MA50',
#        'MID_SPLICE_SLOPE5', 'MID_SPLICE_SLOPE10', 'MID_SPLICE_SLOPE20',
#        'MID_SPLICE_SLOPE50', 'RHT_SPLICE_DELTA', 'RHT_SPLICE_PREV',
#        'RHT_SPLICE_MA5', 'RHT_SPLICE_MA10', 'RHT_SPLICE_MA20',
#        'RHT_SPLICE_MA50', 'RHT_SPLICE_SLOPE5', 'RHT_SPLICE_SLOPE10',
#        'RHT_SPLICE_SLOPE20', 'RHT_SPLICE_SLOPE50', 'LFT_SPLICE_GRADE',
#        'MID_SPLICE_GRADE', 'RHT_SPLICE_GRADE', 'SPLICE_GRADE'],
#       dtype='object')

# %%
# using df_sample dataset (10000 rows only)

# cols = ['CUT_LENGTH', 'CONV_WAIT_TIME', 'LFT_SPLICE_LENGTH',
#        'MID_SPLICE_LENGTH', 'RHT_SPLICE_LENGTH', #'SPLICE_OK', 
#         'PA_S8_L', 'PA_S7_L', 'PA_S6_L',
#        'PA_S5_L', 'PA_S4_L', 'PA_S3_L', 'PA_S2_L', 'PA_S1_ML', 'PA_S1_MR',
#        'PA_S2_R', 'PA_S3_R', 'PA_S4_R', 'PA_S5_R', 'PA_S6_R', 'PA_S7_R',
#        'PA_S8_R', 'LFT_SPLICE_DELTA', 'LFT_SPLICE_PREV', 'LFT_SPLICE_MA5',
#        'LFT_SPLICE_MA10', 'LFT_SPLICE_MA20', 'LFT_SPLICE_MA50',
#        'LFT_SPLICE_SLOPE5', 'LFT_SPLICE_SLOPE10', 'LFT_SPLICE_SLOPE20',
#        'LFT_SPLICE_SLOPE50', 'MID_SPLICE_DELTA', 'MID_SPLICE_PREV',
#        'MID_SPLICE_MA5', 'MID_SPLICE_MA10', 'MID_SPLICE_MA20',
#        'MID_SPLICE_MA50', 'MID_SPLICE_SLOPE5', 'MID_SPLICE_SLOPE10',
#        'MID_SPLICE_SLOPE20', 'MID_SPLICE_SLOPE50', 'RHT_SPLICE_DELTA',
#        'RHT_SPLICE_PREV', 'RHT_SPLICE_MA5', 'RHT_SPLICE_MA10',
#        'RHT_SPLICE_MA20', 'RHT_SPLICE_MA50', 'RHT_SPLICE_SLOPE5',
#        'RHT_SPLICE_SLOPE10', 'RHT_SPLICE_SLOPE20', 'RHT_SPLICE_SLOPE50']
#sns.pairplot(df_pa[cols])

# ycols = ['LFT_SPLICE_DELTA', 'MID_SPLICE_DELTA','RHT_SPLICE_DELTA', 'SPLICE_OK']
# xcols = ['CUT_LENGTH', 'CONV_WAIT_TIME', #'LFT_SPLICE_LENGTH', 'MID_SPLICE_LENGTH', 'RHT_SPLICE_LENGTH','PA_S8_L', 'PA_S7_L', 'PA_S6_L', 'PA_S5_L', 'PA_S4_L', 
#          'PA_S3_L', 'PA_S2_L', 'PA_S1_ML', 'PA_S1_MR','PA_S2_R', 'PA_S3_R', 'PA_S4_R', 'PA_S5_R', 'PA_S6_R', 'PA_S7_R', 'PA_S8_R', 
#          'LFT_SPLICE_PREV', 'LFT_SPLICE_MA5', 'LFT_SPLICE_MA10', # 'LFT_SPLICE_MA20', 'LFT_SPLICE_MA50',
#          'LFT_SPLICE_SLOPE5', 'LFT_SPLICE_SLOPE10', # 'LFT_SPLICE_SLOPE20', 'LFT_SPLICE_SLOPE50', 
#          'MID_SPLICE_PREV', 'MID_SPLICE_MA5', 'MID_SPLICE_MA10', # 'MID_SPLICE_MA20', 'MID_SPLICE_MA50', 
#          'MID_SPLICE_SLOPE5', 'MID_SPLICE_SLOPE10', # 'MID_SPLICE_SLOPE20', 'MID_SPLICE_SLOPE50', 
#          'RHT_SPLICE_PREV', 'RHT_SPLICE_MA5', 'RHT_SPLICE_MA10',# 'RHT_SPLICE_MA20', 'RHT_SPLICE_MA50', 
#          'RHT_SPLICE_SLOPE5', 'RHT_SPLICE_SLOPE10', # 'RHT_SPLICE_SLOPE20', 'RHT_SPLICE_SLOPE50'
#         ]

# ycols = ['LFT_SPLICE_DELTA', 'MID_SPLICE_DELTA','RHT_SPLICE_DELTA', 'SPLICE_OK']
# xcols = ['CUT_LENGTH', 'CONV_WAIT_TIME', 'LFT_SPLICE_LENGTH', 'MID_SPLICE_LENGTH', 'RHT_SPLICE_LENGTH', 
#          'SPLICE_OK', 'BP1_S8_L', 'BP1_S7_L', 'BP1_S6_L', 'BP1_S5_L', 'BP1_S4_L', 'BP1_S3_L', 'BP1_S2_L',
#          'BP1_S1_ML', 'BP1_S1_MR', 'BP1_S2_R', 'BP1_S3_R', 'BP1_S4_R', 'BP1_S5_R', 'BP1_S6_R', 'BP1_S7_R', 
#          'BP1_S8_R', 'BP1_LENGTH', 'LFT_SPLICE_DELTA', 'LFT_SPLICE_PREV', 'LFT_SPLICE_MA5', 'LFT_SPLICE_MA10', 
#          'LFT_SPLICE_MA20', 'LFT_SPLICE_MA50', 'LFT_SPLICE_SLOPE5', 'LFT_SPLICE_SLOPE10', 'LFT_SPLICE_SLOPE20',
#          'LFT_SPLICE_SLOPE50', 'MID_SPLICE_DELTA', 'MID_SPLICE_PREV', 'MID_SPLICE_MA5', 'MID_SPLICE_MA10', 
#          'MID_SPLICE_MA20', 'MID_SPLICE_MA50', 'MID_SPLICE_SLOPE5', 'MID_SPLICE_SLOPE10', 'MID_SPLICE_SLOPE20',
#          'MID_SPLICE_SLOPE50', 'RHT_SPLICE_DELTA', 'RHT_SPLICE_PREV', 'RHT_SPLICE_MA5', 'RHT_SPLICE_MA10',
#          'RHT_SPLICE_MA20', 'RHT_SPLICE_MA50', 'RHT_SPLICE_SLOPE5', 'RHT_SPLICE_SLOPE10', 'RHT_SPLICE_SLOPE20',
#          'RHT_SPLICE_SLOPE50', 'LFT_SPLICE_GRADE', 'MID_SPLICE_GRADE', 'RHT_SPLICE_GRADE', 'SPLICE_GRADE']



# sns.set(style="ticks", color_codes=True)

# g = sns.pairplot(df_sample, x_vars=xcols, y_vars=ycols, hue='SPLICE_GRADE', hue_order=['OK','Bad','Good'],
#                  plot_kws = {'alpha': 0.6, 's': 30, 'edgecolor': 'w'})

# xlabels,ylabels = [],[]

# for ax in g.axes[-1,:]:
#     xlabel = ax.xaxis.get_label_text()
#     xlabels.append(xlabel)
# for ax in g.axes[:,0]:
#     ylabel = ax.yaxis.get_label_text()
#     ylabels.append(ylabel)

# for i in range(len(xlabels)):
#     for j in range(len(ylabels)):
#         g.axes[j,i].xaxis.set_label_text(xlabels[i])
#         g.axes[j,i].yaxis.set_label_text(ylabels[j])

# plt.show()

# %%
# #standardizing data
# cut_length_scaled = StandardScaler().fit_transform(df['CUT_LENGTH'][:,np.newaxis]);
# low_range = cut_length_scaled[cut_length_scaled[:,0].argsort()][:10]
# high_range= cut_length_scaled[cut_length_scaled[:,0].argsort()][-10:]
# print('outer range (low) of the distribution:')
# print(low_range)
# print('\nouter range (high) of the distribution:')
# print(high_range)

# %%
# using df_sample dataset (10000 rows only)

ycols = ['LFT_SPLICE_DELTA', 'MID_SPLICE_DELTA','RHT_SPLICE_DELTA', 'SPLICE_OK']
xcols = ['CUT_LENGTH', 'CONV_WAIT_TIME', 'LFT_SPLICE_LENGTH', 'MID_SPLICE_LENGTH', 'RHT_SPLICE_LENGTH', 
         'SPLICE_OK', 'PA_S8_L', 'PA_S7_L', 'PA_S6_L', 'PA_S5_L', 'PA_S4_L', 'PA_S3_L', 'PA_S2_L',
         'PA_S1_ML', 'PA_S1_MR', 'PA_S2_R', 'PA_S3_R', 'PA_S4_R', 'PA_S5_R', 'PA_S6_R', 'PA_S7_R', 
         'PA_S8_R', 'PART_LENGTH', 'LFT_SPLICE_DELTA', 'LFT_SPLICE_PREV', 'LFT_SPLICE_MA5', 'LFT_SPLICE_MA10', 
         'LFT_SPLICE_MA20', 'LFT_SPLICE_MA50', 'LFT_SPLICE_SLOPE5', 'LFT_SPLICE_SLOPE10', 'LFT_SPLICE_SLOPE20',
         'LFT_SPLICE_SLOPE50', 'MID_SPLICE_DELTA', 'MID_SPLICE_PREV', 'MID_SPLICE_MA5', 'MID_SPLICE_MA10', 
         'MID_SPLICE_MA20', 'MID_SPLICE_MA50', 'MID_SPLICE_SLOPE5', 'MID_SPLICE_SLOPE10', 'MID_SPLICE_SLOPE20',
         'MID_SPLICE_SLOPE50', 'RHT_SPLICE_DELTA', 'RHT_SPLICE_PREV', 'RHT_SPLICE_MA5', 'RHT_SPLICE_MA10',
         'RHT_SPLICE_MA20', 'RHT_SPLICE_MA50', 'RHT_SPLICE_SLOPE5', 'RHT_SPLICE_SLOPE10', 'RHT_SPLICE_SLOPE20',
         'RHT_SPLICE_SLOPE50', 'LFT_SPLICE_GRADE', 'MID_SPLICE_GRADE', 'RHT_SPLICE_GRADE', 'SPLICE_GRADE']

g = sns.PairGrid(df_sample, x_vars=xcols, y_vars=ycols, hue='SPLICE_GRADE', hue_order=[0, 1]) 
# palette="Oranges" or "Blues"
# hue_kws={"marker": ["v", "o", "^"]
g = g.map(plt.scatter, s=30, alpha= 0.6, edgecolor='w')
# plot_kws = {'alpha': 0.6, 's': 40, 'edgecolor': 'w'}

xlabels,ylabels = [],[]

# ax.legend()
g = g.add_legend()

# ax.grid(True)

for ax in g.axes[-1,:]:
    xlabel = ax.xaxis.get_label_text()
    xlabels.append(xlabel)
for ax in g.axes[:,0]:
    ylabel = ax.yaxis.get_label_text()
    ylabels.append(ylabel)

for i in range(len(xlabels)):
    for j in range(len(ylabels)):
        g.axes[j,i].xaxis.set_label_text(xlabels[i])
        g.axes[j,i].yaxis.set_label_text(ylabels[j])

plt.show()

# %%
# %matplotlib inline  
# %matplotlib notebook

# # Splice Delta x Cut Length x Wait Time, or Splice Delta x Moving Average5 x Moving Average10
# fig = plt.figure(figsize=(15, 15))
# ax = fig.add_subplot(111, projection='3d')

# xs = df['LFT_SPLICE_DELTA']
# ys = df['CUT_LENGTH']
# zs = df['CONV_WAIT_TIME']
# ax.scatter(xs, ys, zs, s=50, alpha=0.6, edgecolors='w')

# ax.set_xlabel('Left Splice Delta')
# ax.set_ylabel('Cut Length')
# ax.set_zlabel('Conveyer Wait Time')

# ax.mouse_init()

# plt.show()

# %%
# def core(df, α=.05):
#     mask = (df > df.quantile(α)).all(1) & (df < df.quantile(1 - α)).all(1)
#     return df[mask]

# %%
# cmap = sns.cubehelix_palette(as_cmap=True, dark=0, light=1, reverse=True)

# (df_sample.select_dtypes(include=[np.number])
#    .pipe(core)
#    .pipe(sns.PairGrid)
#    .map_upper(plt.scatter, marker='.', alpha=.25)
#    .map_diag(sns.kdeplot)
#    .map_lower(plt.hexbin, cmap=cmap, gridsize=20)
# );

# %%
df.to_csv('VMI_Data_PA_V02_AK6_090118_032619_mod02.csv', header=True, index=False)

# %%
# https://towardsdatascience.com/visualizing-data-with-pair-plots-in-python-f228cf529166

# %%
# https://stackoverflow.com/questions/42592493/displaying-pair-plot-in-pandas-data-frame/42593334

# %%
# https://towardsdatascience.com/visualizing-data-with-pair-plots-in-python-f228cf529166

# %%
# https://stackoverflow.com/questions/42592493/displaying-pair-plot-in-pandas-data-frame/42593334

# %%
# https://jovianlin.io/data-visualization-seaborn-part-3/

# %%
# https://stackoverflow.com/questions/32889590/seaborn-pairgrid-using-kdeplot-with-2-hues

# %%
# https://github.com/mwaskom/seaborn/issues/933

# %%
# Example of color selection
# import matplotlib.pyplot as plt
# import pandas as pd

# carat = [5, 10, 20, 30, 5, 10, 20, 30, 5, 10, 20, 30]
# price = [100, 100, 200, 200, 300, 300, 400, 400, 500, 500, 600, 600]
# color =['D', 'D', 'D', 'E', 'E', 'E', 'F', 'F', 'F', 'G', 'G', 'G',]

# df = pd.DataFrame(dict(carat=carat, price=price, color=color))

# fig, ax = plt.subplots()

# colors = {'D':'red', 'E':'blue', 'F':'green', 'G':'black'}

# ax.scatter(df['carat'], df['price'], c=df['color'].apply(lambda x: colors[x]))

# plt.show()
